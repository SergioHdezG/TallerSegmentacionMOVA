# %% [markdown]
# # Taller de segmentación de imágenes
#
# La segementación semántica sobre imágenes consiste en, dada una imagen, determinar a que objeto de esa imagen corresponde cada pixel. Específicamente, consiste en un problema denso de clasificación de imágenes, es decir, en lugar de determinar a que clase corresponde una imagen completa, queremos determinar la clase de cada lugar de la imagen obteniendo así otras propiedades de los objetos como forma o tamaño.

# %% [markdown]
# ![1](https://www.cityscapes-dataset.com/wordpress/wp-content/uploads/2015/07/koeln00.png)

# %% [markdown]
# # Arquitecturas neuronales para segmentación
#
# La arquitectura de red más comunmente utilizada para realizar la tarea de segmentación sobre imágenes es la de los Autoencoder y existen multiples tipos y versiones. A continuación enumeramos algunos:
# - Autoencoders (AEs)
# - U-Net
# - V-Net
# - Autoencoder Variacional (VAE)

# %% [markdown]
# # Autoencoder (AE)
#
# El Autoencoder (AE) es la primera de las versiones, la más básica y de la que parten el resto de tipos de autoencoder.
#
# Consiste en una red neuronal, ya sea densa o convolucional, que presenta un cuello de botella. La función de este cuello de botella es reducir las dimensiones (comprimir) de los datos de entrada a un vector de pequeñas dimensiones que se conoce con el nombre de **huella latente**.
#
# Se compone de dos partes principales:
# - **Codificador:** Red neuronal que comprime los datos de entrada en la huella latente.
# - **Decodificador:** Red neuronal que transforma la huella latente en un vector de grandes dimensiones que puede ser: los tatos originales reconstruidos o una transformación de estos (Imagen de profundidas, flujo óptico, segmentación, etc)
#
# ![AE](https://raw.githubusercontent.com/SergioHdezG/TallerSegmentacionMOVA/master/aerquitecturaVAE.png)
#
# KRAMER, Mark A. Nonlinear principal component analysis using autoassociative neural networks. AIChE journal, 1991, vol. 37, no 2, p. 233-243.  https://doi.org/10.1002/aic.690370209

# %% [markdown]
# # Ejemplo práctico de Autoencoder
# A continuación comenzamos la parte de implementación de este taller para aprender como construir un autoencoder en Keras.
#
# ## Recursos
#
# En este notebook utilizamos la librería de cómputo Tensorflow (TF) y específicamente su módulo para deep learning Keras
#
# TensorFlow (TF2): https://www.tensorflow.org/
#
# Keras: https://keras.io/
#
# Como dataset se va a utilizar el Conference Video Segmentation Dataset (https://github.com/kuangzijian/Flow-Based-Video-Segmentation):
#
#   * Data url: https://drive.google.com/file/d/13JKwoCaoSWQAjJ1YLVfV6AHvm8by09fP/view
#   * Cuatro videos estilo conferencia con segmentación de las personas.
#   * Dataset creado semi artificialmente utilizando una pantalla verde de fondo.
#
# Input:
#
# ![Input Image](https://raw.githubusercontent.com/kuangzijian/Flow-Based-Video-Segmentation/master/readme_imgs/with_bg.jpg)
#
# Ground truth:
#
# ![Ground truth](https://raw.githubusercontent.com/kuangzijian/Flow-Based-Video-Segmentation/master/readme_imgs/ground_truth.jpg)

# %% [markdown]
# ## Carga y preprocesado de datos
#
# El primer paso para resolver cualquier problema de machine learning es cargar, visualizar y preprocesar el conjunto de datos que se va a utilizar.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras import backend as K

import os
import cv2
import numpy as np
from matplotlib import image as plt_image
import matplotlib.pyplot as plt

# %% [markdown]
# El dataset se encuentra en: https://drive.google.com/file/d/1ChXfmym3HinaQ_3Bg37xQdUleaFb5F70/view?usp=sharing
#
# Añadelo a tu google drive, no es necesario que lo descargues

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# El dataset se encuentra comprimido, hay que descomprimirlo.

# %%
# !unzip -u "/content/drive/MyDrive/Colab Notebooks/taller segmentacion/taller_segmemtacion_MOVA/ConferenceVideoSegmentationDataset.zip" -d "/content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP"
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/taller segmentacion/taller_segmemtacion_MOVA/ConferenceVideoSegmentationDataset.zip
#    creating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_1.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_10.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_100.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_101.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_102.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_103.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_104.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_105.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_106.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_107.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_108.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_109.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_11.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_110.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_111.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_112.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_113.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_114.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_115.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_116.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_117.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_118.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_119.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_12.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_120.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_121.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_122.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_123.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_124.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_125.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_126.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_127.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_128.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_129.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_13.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_130.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_131.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_132.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_133.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_134.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_135.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_136.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_137.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_138.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_139.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_14.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_140.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_141.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_142.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_143.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_144.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_145.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_146.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_147.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_148.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_149.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_15.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_150.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_151.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_152.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_153.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_154.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_155.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_156.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_157.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_158.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_159.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_16.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_160.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_161.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_162.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_163.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_164.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_165.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_166.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_167.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_168.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_169.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_17.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_170.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_171.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_172.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_173.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_174.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_175.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_176.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_177.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_178.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_179.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_18.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_180.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_181.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_182.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_183.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_184.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_185.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_186.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_187.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_188.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_189.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_19.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_190.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_191.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_192.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_193.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_194.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_195.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_196.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_197.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_198.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_199.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_2.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_20.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_200.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_201.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_202.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_203.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_204.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_205.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_206.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_207.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_208.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_209.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_21.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_210.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_211.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_212.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_213.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_214.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_215.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_216.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_217.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_218.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_219.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_22.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_220.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_221.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_222.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_223.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_224.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_225.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_226.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_227.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_228.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_229.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_23.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_230.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_231.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_232.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_233.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_234.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_235.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_236.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_237.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_238.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_239.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_24.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_240.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_241.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_242.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_243.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_244.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_245.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_246.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_247.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_248.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_249.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_25.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_250.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_251.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_252.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_253.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_254.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_255.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_256.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_257.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_258.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_259.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_26.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_260.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_261.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_262.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_263.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_264.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_265.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_266.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_267.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_268.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_269.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_27.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_270.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_271.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_272.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_273.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_274.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_275.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_276.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_277.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_278.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_279.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_28.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_280.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_281.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_282.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_283.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_284.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_285.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_286.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_287.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_288.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_289.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_29.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_290.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_291.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_292.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_293.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_294.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_295.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_296.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_297.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_298.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_299.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_3.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_30.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_300.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_301.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_302.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_303.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_304.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_305.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_306.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_307.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_308.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_309.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_31.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_310.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_311.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_312.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_313.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_314.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_315.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_316.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_317.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_318.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_319.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_32.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_320.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_321.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_322.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_323.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_324.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_325.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_326.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_327.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_328.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_329.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_33.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_330.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_331.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_332.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_333.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_334.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_335.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_336.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_337.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_338.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_339.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_34.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_340.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_341.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_342.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_343.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_344.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_345.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_346.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_347.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_348.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_349.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_35.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_350.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_351.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_352.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_353.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_354.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_355.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_356.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_357.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_358.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_359.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_36.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_360.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_361.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_362.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_363.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_364.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_365.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_366.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_367.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_368.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_369.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_37.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_370.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_371.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_372.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_373.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_374.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_375.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_376.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_377.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_378.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_379.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_38.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_380.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_381.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_382.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_383.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_384.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_385.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_386.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_387.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_388.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_389.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_39.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_390.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_391.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_392.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_393.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_394.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_395.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_396.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_397.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_398.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_399.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_4.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_40.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_400.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_401.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_402.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_403.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_404.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_405.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_406.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_407.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_408.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_409.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_41.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_410.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_411.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_412.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_413.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_414.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_415.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_416.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_417.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_418.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_419.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_42.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_420.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_421.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_422.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_423.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_424.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_425.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_426.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_427.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_428.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_429.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_43.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_430.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_431.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_432.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_433.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_434.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_435.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_436.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_437.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_438.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_439.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_44.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_440.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_441.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_442.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_443.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_444.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_445.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_446.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_447.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_448.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_449.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_45.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_450.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_451.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_452.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_453.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_454.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_455.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_456.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_457.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_458.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_459.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_46.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_460.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_461.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_462.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_463.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_464.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_465.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_466.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_467.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_468.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_469.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_47.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_470.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_471.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_472.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_473.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_474.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_475.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_476.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_477.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_478.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_479.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_48.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_480.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_481.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_482.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_483.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_484.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_485.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/ground_truth_testing/gt3_486.jpg
# ...
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_373.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_374.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_375.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_376.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_377.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_378.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_379.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_38.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_380.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_381.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_382.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_383.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_384.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_385.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_386.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_387.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_388.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_389.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_39.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_390.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_391.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_392.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_393.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_394.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_395.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_396.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_397.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_398.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_399.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_4.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_40.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_400.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_401.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_402.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_403.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_404.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_405.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_406.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_407.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_408.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_409.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_41.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_410.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_411.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_412.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_413.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_414.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_415.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_416.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_417.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_418.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_419.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_42.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_420.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_421.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_422.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_423.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_424.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_425.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_426.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_427.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_428.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_429.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_43.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_430.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_431.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_432.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_433.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_434.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_435.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_436.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_437.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_438.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_439.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_44.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_440.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_441.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_442.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_443.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_444.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_445.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_45.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_46.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_47.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_48.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_49.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_5.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_50.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_51.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_52.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_53.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_54.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_55.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_56.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_57.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_58.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_59.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_6.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_60.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_61.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_62.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_63.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_64.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_65.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_66.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_67.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_68.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_69.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_7.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_70.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_71.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_72.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_73.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_74.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_75.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_76.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_77.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_78.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_79.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_8.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_80.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_81.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_82.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_83.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_84.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_85.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_86.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_87.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_88.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_89.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_9.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_90.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_91.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_92.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_93.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_94.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_95.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_96.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_97.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_98.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/original_training/original5_99.jpg

# %% [markdown]
# Cargamos los nombres de los ficheros en memoria y ordenamos los datos para que coincidan las imágenes de entrada con las máscaras de segmentación.

# %%
data_path = "/content/drive/MyDrive/Colab Notebooks/taller segmentacion/TMP/"

training_in = os.listdir(os.path.join(data_path, "original_training"))
training_label = os.listdir(os.path.join(data_path, "ground_truth_training"))

# Ordenamos las imágenes por sequencia de video y por fotograma
training_in.sort(key= lambda x : (int(x.split("_")[0].split("l")[1]), int(x.split(".")[0].split("_")[1])))
training_label.sort(key= lambda x : (int(x.split("_")[0].split("t")[1]), int(x.split(".")[0].split("_")[1])))

print('Training size: ', len(training_in))
print(training_in[:10])
print(training_label[:10])
# Out:
# Training size:  1326
# ['original1_1.jpg', 'original1_2.jpg', 'original1_3.jpg', 'original1_4.jpg', 'original1_5.jpg', 'original1_6.jpg', 'original1_7.jpg', 'original1_8.jpg', 'original1_9.jpg', 'original1_10.jpg']
# ['gt1_1.jpg', 'gt1_2.jpg', 'gt1_3.jpg', 'gt1_4.jpg', 'gt1_5.jpg', 'gt1_6.jpg', 'gt1_7.jpg', 'gt1_8.jpg', 'gt1_9.jpg', 'gt1_10.jpg']

# %% [markdown]
# Cargamos los datos de entrenamiento en un numpy array.
#
# En este ejemplo ce cargan solo las 100 primeras imágenes.

# %%
x_train = [plt_image.imread(os.path.join(data_path, "original_training", name)) for name in training_in[:100]]
y_train = [plt_image.imread(os.path.join(data_path, "ground_truth_training", name)) for name in training_label[:100]]
print('Training size: ', len(x_train))
# Out:
# Training size:  100

# %% [markdown]
# Para este caso de ejemplo vamos a ajustar el tamaño de los datos. Lo vamos a reducir desde su tamaño inicial (360, 640) a (128, 128) por tres motivos:
#
#
# 1.   Para ajustarlos al tamaño de entrada que nos interesa en la red neuronal
# 2.   Para que al realizar convoluciones con stride=2 no quede ninguna dimensión imapar. Si se diese ese caso luego tendríamos problemas para recuperar el tamaño original a la salida del autoencoder.
# 3.   Para simplificar y acelerar el procesamiento a efectos prácticos de este taller.

# %%
for i in range(len(x_train)):
    x_train[i] = cv2.resize(x_train[i], (128, 128))
    y_train[i] = cv2.resize(y_train[i], (128, 128))

# %% [markdown]
# Realizamos una visualización de los datos contenidos en el dataset.

# %%
n_img = np.random.randint(0, len(x_train))
img_in = x_train[n_img]
img_label = y_train[n_img]

print('Input image shape: ', img_in.shape)
print('Label image shape: ', img_label.shape)

plt.subplot(2, 2, 1)
plt.imshow(img_in)

plt.subplot(2, 2, 2)
plt.imshow(img_label)

n_img = np.random.randint(0, len(x_train))
img_in = x_train[n_img]
img_label = y_train[n_img]

plt.subplot(2, 2, 3)
plt.imshow(img_in)

plt.subplot(2, 2, 4)
plt.imshow(img_label)

plt.show()

print("Train images range: : [", np.amin(img_in), ", ", np.amax(img_in), "]")
print("Test images range: : [", np.amin(img_label), ",", np.amax(img_label), "]")
# Out:
# Input image shape:  (128, 128, 3)
# Label image shape:  (128, 128, 3)
# Train images range: : [ 0 ,  255 ]
# Test images range: : [ 0 , 255 ]

# %% [markdown]
# Como se puede observar en la celda anterior, los datos se encuentran en el rango de valores [0, 255]. Nos interesa normalizarlos al rango [0, 1] y convertirlos a tipo float32.
#
# Posteriormente nos quedamos solo con uno de los tres canales de las imágenes segmentadas ya que se encuentran triplicados.

# %%
# Normalizamos los datos de entrada en rango [0, 1]
x_train = np.array(x_train, dtype=np.float32) / 255.
y_train = np.array(y_train, dtype=np.float32) / 255.

# Nos quedamos solo con el primer canal de las etiquetas
y_train = np.expand_dims(y_train[:, :, :, 0], axis=-1)

print('Input image shape: ', x_train[0].shape)
print('Label image shape: ', y_train[0].shape)

print("Train images range: : [", np.amin([x_train[0]]), ", ", np.amax(x_train[0]), "]")
print("Test images range: : [", np.amin(y_train[0]), ",", np.amax(y_train[0]), "]")
# Out:
# Input image shape:  (128, 128, 3)
# Label image shape:  (128, 128, 1)
# Train images range: : [ 0.0 ,  1.0 ]
# Test images range: : [ 0.0 , 1.0 ]

# %% [markdown]
# Separamos un subconjunto de los datos para hacer validación.

# %%
# separamos un subconjunto de validación

val_split = 0.15
val_split = int(x_train.shape[0] * val_split)
val_idx = np.random.choice(x_train.shape[0], val_split, replace=False)  # Seleccionamos varios índices aleatorios
train_mask = np.array([False if i in val_idx else True for i in range(x_train.shape[0])])  # Creamos una máscara para seleccionar los datos de entrenamiento

x_val = x_train[val_idx]  # Seleccionamos datos de validacón
y_val = y_train[val_idx]

x_train = x_train[train_mask]  # Seleccionamos datos de entrenamiento
y_train = y_train[train_mask]

print('Train samples: ', x_train.shape[0])
print('Validation samples: ', x_val.shape[0])
# Out:
# Train samples:  85
# Validation samples:  15

# %% [markdown]
# ## Contruir el Autoencoder
#
# ### Encoder

# %%
# Construir el codificador

input_shape = (128, 128, 3)  # Definimos el tamaño de las imágenes de entrada 
latent_dim = 256  # Tamaño de la huella latente

encoder_input = Input(shape=input_shape, name='encoder_input')  # Tensor de entrada

# Aplicamos convoluciones traspuestas con stride=2 para reducir las dimensiones de los datos poco a poco
enc1 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=2,
            padding='same')(encoder_input)

enc2 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=2,
            padding='same')(enc1)

enc3 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=2,
            padding='same')(enc2)

enc4 = Conv2D(filters=16,
            kernel_size=3,
            activation='relu',
            strides=2,
            padding='same')(enc3)

enc5 = Flatten()(enc4)

# Vector latente de dimensión latent_dim  
huella_latente = Dense(latent_dim, activation="linear", name='latent')(enc5)

# %% [markdown]
# ### Decoder

# %% [markdown]
# A la hora de construir el decodificador hay que prestar especial atención a las dimensiones de los datos ya que queremos reconstruir una imagene del mismo tamaño que la original.
#
# El tamaño de entrada de nuestra red es (128, 128, 3), en la salida de la última capa convoluconal el tamaó de los datos es  (8, 8, 16).y el tamaño de la huella latente es 256.
#
# Al construir el decodificador hay que hacer el camino inverso. En este caso, convertiremos la huella latente en un vector de 1024 valores que daremos forma de imagen (8, 8, 16) con una capa Reshape. Una vez tenemos una imagene de la misma dimensión que la de la capa enc4 solo tenemos que desacer los pasos utilizando convoluciones traspuestas. Finalmente, se obtiene una imagen de tamaño (128, 128, 8) que se procesará por una última capa con el número de filtros igual al número de canales de la imagen objetivo (en este caso uno) (128, 128, 1).

# %%
# Contruir el decodificador

enc4_shape = K.int_shape(enc4)  # Forma del vector enc4 (None, 8, 8, 16)

# Esta capa densa transforma la huella latente en un vector con el mismo número de píxeles que la salida de la capa enc4
dec = Dense(enc4_shape[1] * enc4_shape[2] * enc4_shape[3], activation='relu')(huella_latente) 

# Transformamos el vector dec y le damos forma de imagen (8, 8, 16)
dec1 = Reshape((enc4_shape[1], enc4_shape[2], enc4_shape[3]))(dec)

# Aplicamos convoluciones traspuestas con stride=2 hasta alcanzar la forma (128, 128, 8)
dec2 = Conv2DTranspose(filters=16,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec1)

dec3 = Conv2DTranspose(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec2)

dec4 = Conv2DTranspose(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec3)

dec5 = Conv2DTranspose(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec4)

# Transformamos el vector dec5 para que tenga el número de canales deseado
decoder_output = Conv2DTranspose(filters=1,
                      kernel_size=3,
                      activation='sigmoid',
                      padding='same',
                      name='decoder_output')(dec5)  # Activación sigmoide para que las salidas estén en rango [0, 1]

# %% [markdown]
# Construimos y compilamos el modelo en keras

# %%
autoencoder =  tf.keras.models.Model(encoder_input, decoder_output, name='AE')

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4),
                    loss=tf.keras.losses.BinaryCrossentropy(),
                    metrics=tf.keras.metrics.BinaryAccuracy(threshold=0.5))

autoencoder.summary()
# Out:
# Model: "AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 128, 128, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 8)         224
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 8)         584
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 8)         584
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 8)           584
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  latent (Dense)              (None, 256)               131328
#
#  dense_3 (Dense)             (None, 512)               131584
#
#  reshape_3 (Reshape)         (None, 8, 8, 8)           0
#
#  conv2d_transpose_11 (Conv2D  (None, 16, 16, 16)       1168
#  Transpose)
#
#  conv2d_transpose_12 (Conv2D  (None, 32, 32, 8)        1160
#  Transpose)
#
#  conv2d_transpose_13 (Conv2D  (None, 64, 64, 8)        584
#  Transpose)
#
#  conv2d_transpose_14 (Conv2D  (None, 128, 128, 8)      584
#  Transpose)
#
#  decoder_output (Conv2DTrans  (None, 128, 128, 1)      73
#  pose)
#
# =================================================================
# Total params: 268,457
# Trainable params: 268,457
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# ## Entrenamiento

# %%
batch_size = 8
epochs = 50

autoencoder.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, shuffle=True, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 3s 116ms/step - loss: 0.6928 - binary_accuracy: 0.6720 - val_loss: 0.6924 - val_binary_accuracy: 0.6912
# Epoch 2/50
# 11/11 [==============================] - 1s 90ms/step - loss: 0.6921 - binary_accuracy: 0.6923 - val_loss: 0.6917 - val_binary_accuracy: 0.6913
# Epoch 3/50
# 11/11 [==============================] - 1s 94ms/step - loss: 0.6913 - binary_accuracy: 0.6923 - val_loss: 0.6908 - val_binary_accuracy: 0.6913
# Epoch 4/50
# 11/11 [==============================] - 1s 92ms/step - loss: 0.6902 - binary_accuracy: 0.6923 - val_loss: 0.6895 - val_binary_accuracy: 0.6912
# Epoch 5/50
# 11/11 [==============================] - 1s 92ms/step - loss: 0.6886 - binary_accuracy: 0.6921 - val_loss: 0.6873 - val_binary_accuracy: 0.6907
# Epoch 6/50
# 11/11 [==============================] - 1s 91ms/step - loss: 0.6855 - binary_accuracy: 0.6914 - val_loss: 0.6828 - val_binary_accuracy: 0.6897
# Epoch 7/50
# 11/11 [==============================] - 1s 91ms/step - loss: 0.6792 - binary_accuracy: 0.6899 - val_loss: 0.6736 - val_binary_accuracy: 0.6877
# Epoch 8/50
# 11/11 [==============================] - 1s 90ms/step - loss: 0.6668 - binary_accuracy: 0.6883 - val_loss: 0.6570 - val_binary_accuracy: 0.6871
# Epoch 9/50
# 11/11 [==============================] - 1s 91ms/step - loss: 0.6466 - binary_accuracy: 0.6881 - val_loss: 0.6328 - val_binary_accuracy: 0.6873
# Epoch 10/50
# 11/11 [==============================] - 1s 91ms/step - loss: 0.6192 - binary_accuracy: 0.6888 - val_loss: 0.6020 - val_binary_accuracy: 0.6886
# Epoch 11/50
# 11/11 [==============================] - 1s 90ms/step - loss: 0.5854 - binary_accuracy: 0.6899 - val_loss: 0.5651 - val_binary_accuracy: 0.6891
# Epoch 12/50
# 11/11 [==============================] - 1s 91ms/step - loss: 0.5459 - binary_accuracy: 0.6905 - val_loss: 0.5237 - val_binary_accuracy: 0.6897
# Epoch 13/50
# 11/11 [==============================] - 1s 93ms/step - loss: 0.5031 - binary_accuracy: 0.6911 - val_loss: 0.4815 - val_binary_accuracy: 0.6903
# Epoch 14/50
# 11/11 [==============================] - 1s 93ms/step - loss: 0.4620 - binary_accuracy: 0.6915 - val_loss: 0.4436 - val_binary_accuracy: 0.6907
# Epoch 15/50
# 11/11 [==============================] - 1s 92ms/step - loss: 0.4264 - binary_accuracy: 0.6919 - val_loss: 0.4127 - val_binary_accuracy: 0.6910
# Epoch 16/50
# 11/11 [==============================] - 1s 94ms/step - loss: 0.3983 - binary_accuracy: 0.6920 - val_loss: 0.3894 - val_binary_accuracy: 0.6910
# Epoch 17/50
# 11/11 [==============================] - 1s 93ms/step - loss: 0.3770 - binary_accuracy: 0.6921 - val_loss: 0.3716 - val_binary_accuracy: 0.6911
# Epoch 18/50
# 11/11 [==============================] - 1s 93ms/step - loss: 0.3606 - binary_accuracy: 0.6922 - val_loss: 0.3576 - val_binary_accuracy: 0.6913
# Epoch 19/50
# 11/11 [==============================] - 1s 95ms/step - loss: 0.3477 - binary_accuracy: 0.6922 - val_loss: 0.3463 - val_binary_accuracy: 0.6913
# Epoch 20/50
# 11/11 [==============================] - 1s 96ms/step - loss: 0.3371 - binary_accuracy: 0.6923 - val_loss: 0.3367 - val_binary_accuracy: 0.6913
# Epoch 21/50
# 11/11 [==============================] - 1s 97ms/step - loss: 0.3281 - binary_accuracy: 0.6923 - val_loss: 0.3284 - val_binary_accuracy: 0.6912
# Epoch 22/50
# 11/11 [==============================] - 1s 97ms/step - loss: 0.3204 - binary_accuracy: 0.6922 - val_loss: 0.3213 - val_binary_accuracy: 0.6912
# Epoch 23/50
# 11/11 [==============================] - 1s 99ms/step - loss: 0.3139 - binary_accuracy: 0.6922 - val_loss: 0.3154 - val_binary_accuracy: 0.6912
# Epoch 24/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.3085 - binary_accuracy: 0.6923 - val_loss: 0.3105 - val_binary_accuracy: 0.6912
# Epoch 25/50
# 11/11 [==============================] - 1s 95ms/step - loss: 0.3040 - binary_accuracy: 0.6923 - val_loss: 0.3065 - val_binary_accuracy: 0.6913
# Epoch 26/50
# 11/11 [==============================] - 1s 95ms/step - loss: 0.3002 - binary_accuracy: 0.6924 - val_loss: 0.3031 - val_binary_accuracy: 0.6914
# Epoch 27/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2970 - binary_accuracy: 0.6925 - val_loss: 0.3003 - val_binary_accuracy: 0.6914
# Epoch 28/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2943 - binary_accuracy: 0.6925 - val_loss: 0.2980 - val_binary_accuracy: 0.6914
# Epoch 29/50
# 11/11 [==============================] - 1s 95ms/step - loss: 0.2920 - binary_accuracy: 0.6925 - val_loss: 0.2959 - val_binary_accuracy: 0.6915
# Epoch 30/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2899 - binary_accuracy: 0.6926 - val_loss: 0.2939 - val_binary_accuracy: 0.6916
# Epoch 31/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2879 - binary_accuracy: 0.6927 - val_loss: 0.2922 - val_binary_accuracy: 0.6916
# Epoch 32/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2862 - binary_accuracy: 0.7407 - val_loss: 0.2905 - val_binary_accuracy: 0.8872
# Epoch 33/50
# 11/11 [==============================] - 1s 102ms/step - loss: 0.2846 - binary_accuracy: 0.8890 - val_loss: 0.2891 - val_binary_accuracy: 0.8903
# Epoch 34/50
# 11/11 [==============================] - 1s 93ms/step - loss: 0.2831 - binary_accuracy: 0.8918 - val_loss: 0.2878 - val_binary_accuracy: 0.8930
# Epoch 35/50
# 11/11 [==============================] - 1s 96ms/step - loss: 0.2817 - binary_accuracy: 0.8938 - val_loss: 0.2865 - val_binary_accuracy: 0.8956
# Epoch 36/50
# 11/11 [==============================] - 1s 100ms/step - loss: 0.2803 - binary_accuracy: 0.8954 - val_loss: 0.2854 - val_binary_accuracy: 0.8964
# Epoch 37/50
# 11/11 [==============================] - 1s 99ms/step - loss: 0.2791 - binary_accuracy: 0.8960 - val_loss: 0.2842 - val_binary_accuracy: 0.8968
# Epoch 38/50
# 11/11 [==============================] - 1s 99ms/step - loss: 0.2779 - binary_accuracy: 0.8962 - val_loss: 0.2831 - val_binary_accuracy: 0.8970
# Epoch 39/50
# 11/11 [==============================] - 1s 101ms/step - loss: 0.2768 - binary_accuracy: 0.8967 - val_loss: 0.2820 - val_binary_accuracy: 0.8974
# Epoch 40/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2757 - binary_accuracy: 0.8970 - val_loss: 0.2811 - val_binary_accuracy: 0.8977
# Epoch 41/50
# 11/11 [==============================] - 1s 97ms/step - loss: 0.2746 - binary_accuracy: 0.8974 - val_loss: 0.2803 - val_binary_accuracy: 0.8984
# Epoch 42/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2736 - binary_accuracy: 0.8982 - val_loss: 0.2792 - val_binary_accuracy: 0.8992
# Epoch 43/50
# 11/11 [==============================] - 1s 96ms/step - loss: 0.2726 - binary_accuracy: 0.8987 - val_loss: 0.2784 - val_binary_accuracy: 0.8994
# Epoch 44/50
# 11/11 [==============================] - 1s 97ms/step - loss: 0.2717 - binary_accuracy: 0.8990 - val_loss: 0.2773 - val_binary_accuracy: 0.9000
# Epoch 45/50
# 11/11 [==============================] - 1s 97ms/step - loss: 0.2708 - binary_accuracy: 0.8997 - val_loss: 0.2764 - val_binary_accuracy: 0.9005
# Epoch 46/50
# 11/11 [==============================] - 1s 99ms/step - loss: 0.2699 - binary_accuracy: 0.9001 - val_loss: 0.2757 - val_binary_accuracy: 0.9008
# Epoch 47/50
# 11/11 [==============================] - 1s 95ms/step - loss: 0.2690 - binary_accuracy: 0.9005 - val_loss: 0.2750 - val_binary_accuracy: 0.9014
# Epoch 48/50
# 11/11 [==============================] - 1s 98ms/step - loss: 0.2682 - binary_accuracy: 0.9009 - val_loss: 0.2742 - val_binary_accuracy: 0.9017
# Epoch 49/50
# 11/11 [==============================] - 1s 96ms/step - loss: 0.2674 - binary_accuracy: 0.9014 - val_loss: 0.2733 - val_binary_accuracy: 0.9025
# Epoch 50/50
# 11/11 [==============================] - 1s 97ms/step - loss: 0.2665 - binary_accuracy: 0.9020 - val_loss: 0.2727 - val_binary_accuracy: 0.9026

# %% [markdown]
# Descomentar la siguiente celda para guardar los pesos del autoencoder.

# %%
# path = '/content/drive/MyDrive/Colab Notebooks/taller segmentacion/taller_segmemtacion_MOVA/saved_models/AE'
# autoencoder.save_weights(path + ".h5")

# %% [markdown]
# Decomentar la siguiente celda para cargar los pesos del autencoder

# %%
# # path = '/content/drive/MyDrive/Colab Notebooks/taller segmentacion/taller_segmemtacion_MOVA/saved_models/AE'
# path = '/content/drive/MyDrive/Colab Notebooks/teller segmentacion/Modelos_salvados/AE_decoder_64_64_128_256'

# # load weights into  model
# autoencoder.load_weights(path + ".h5")


# # # Si fuesemos a reentrenar necesitariamos compilar el modelo de nuevo
# # vae.compile(optimizer='adam')

# %% [markdown]
# ## Testing
# En primer lugar vamos a pasar la red sobre el conjunto de test para ver si ha
# generalizado.
#
# ### Carga y preprocesado de datos de test
# Para esto tenemos que cargar en primer lugar el conjunto de test.

# %%
testing_in = os.listdir(os.path.join(data_path, "original_testing"))
testing_label = os.listdir(os.path.join(data_path, "ground_truth_testing"))

# Ordenamos las imágenes por sequencia
testing_in.sort(key=lambda x: (int(x.split("_")[0].split("l")[1]), int(x.split(".")[0].split("_")[1])))
testing_label.sort(key=lambda x: (int(x.split("_")[0].split("t")[1]), int(x.split(".")[0].split("_")[1])))
x_test = [plt_image.imread(os.path.join(data_path, "original_testing", name)) for name in testing_in[:100]]
y_test = [plt_image.imread(os.path.join(data_path, "ground_truth_testing", name)) for name in testing_label[:100]]

# %% [markdown]
# Aplicaremos las mismas transformaciones que en el conjunto de entrenamiento, es decir, redimensionaremos las imágenes hasta el tamaño de entrada de la red y normalizaremos los datos.

# %%
for i in range(len(x_test)):
    x_test[i] = cv2.resize(x_test[i], (128, 128))
    y_test[i] = cv2.resize(y_test[i], (128, 128))

# Normalizamos los datos de entrada en rango [0, 1]
x_test = np.array(x_test) / 255.
y_test = np.array(y_test) / 255.
y_test = np.expand_dims(y_test[:, :, :, 1], axis=-1)

# %% [markdown]
# La función evaluate realiza un predict sobre cada entrada del conjunto de test y extrae las métricas que hayamos indicado al compilar el modelo.

# %%
autoencoder.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 13/13 [==============================] - 0s 28ms/step - loss: 1.0120 - binary_accuracy: 0.7063
# [1.0120105743408203, 0.706268310546875]

# %% [markdown]
# Por último, vamos a visualizar algunos de los resultados.
#
# La siguiente celda selecciona varias imágenes aleatorias y muestra su salida.

# %%
# Selecionamos varias imágenes aleatorias del conjunto de test
examples_index = np.random.choice(x_test.shape[0], figsize*2)
examples = x_test[examples_index]

# Realizamos la predicción con el autoencoder
predictions = autoencoder.predict(examples)

# Ponemos a 1.0 los píxeles pertenecientes al primer plano y a 0. los pertenecientes al fondo
predictions[predictions > 0.5] = 1.0
predictions[predictions <= 0.5] = 0.0

predictions = np.squeeze(predictions, axis=-1)  # (w, h, 1) -> (w, h)

# Preparamos la figura de matplotlib
figsize = 5
num_examples_to_generate = figsize*figsize

fig = plt.figure()
fig.suptitle('Resultados segmentación')

for i in range(figsize*2):

    plt.subplot(4, figsize, i+1)
    plt.imshow(examples[i])
    plt.subplot(4, figsize, i + 1 + figsize*2)
    plt.imshow(predictions[i], cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# # U-Net
#
# U-Net es una arquitectura basada en el autoencoder, completamente convolucional y con conexiones residuales.

# %% [markdown]
# ![u-net-architecture.png](data:image/png;base64,...)

# %% [markdown]
# Ronneberger O., Fischer P., Brox T. (2015) U-Net: Convolutional Networks for Biomedical Image Segmentation. In: Navab N., Hornegger J., Wells W., Frangi A. (eds) Medical Image Computing and Computer-Assisted Intervention – MICCAI 2015. MICCAI 2015. Lecture Notes in Computer Science, vol 9351. Springer, Cham. https://doi.org/10.1007/978-3-319-24574-4_28

# %% [markdown]
# ## Construcción de U-Net
# A continuación vamos a ver como se construiría una U-Net.
# En este caso vamos a dividir la red igualmente en dos partes: Codificador y Decodificador.

# %% [markdown]
# ## Datos Categóricos
# Para este ejemplo vamos a coger el mismo dataset que se ha utilizado en el ejemplo anterior y lo vamos a convertir en un problema categórico en lugar de un problema binario.
#
# Originalmente el problema de la segmentación del primer plano se ha planteado como un problema en el que los píxeles de una máscara con valor mayor que 0.5 (umbral que hemos elegido nosotros) pertenecen al primer plano y los los menores al fondo.
#
# Lo que queremos hacer ahora es convertirlo en un problema de clasificación en el que obtengamos dos máscaras, una para el primer plano y una para el fondo. Por lo tanto la máscara de segmentación que obtengamos como salida de la red estará formada por dos máscaras y tendra forma (128, 128, 2)

# %%
y_train_foreground = y_train[:]
y_train_background = np.abs(y_train[:] - 1)  # Invertimos la máscara para crear el fondo

fig = plt.figure()

plt.subplot(1, 3, 1)
plt.imshow(x_train[0])

plt.subplot(1, 3, 2)
im_fg = np.squeeze(y_train_foreground[0], axis=-1)
plt.imshow(im_fg)

plt.subplot(1, 3, 3)
im_bg = np.squeeze(y_train_background[0], axis=-1)
plt.imshow(im_bg)

plt.axis('off')
plt.show()

y_train_unet = np.concatenate((y_train_background, y_train_foreground), axis=-1)
print(y_train_unet.shape)

y_val_foreground = y_val[:]
y_val_background = np.abs(y_val[:] - 1)

y_val_unet = np.concatenate((y_val_foreground, y_val_background), axis=-1)
print(y_val_unet.shape)

y_test_foreground = y_test[:]
y_test_background = np.abs(y_test[:] - 1)

y_test_unet = np.concatenate((y_test_background, y_test_foreground), axis=-1)
print(y_test_unet.shape)
# Out:
# (85, 128, 128, 2)
# (15, 128, 128, 2)
# (100, 128, 128, 4)

# %% [markdown]
# ### Encoder

# %%
# Construir el codificador de U-Net

input_shape = (128, 128, 3)  # Definimos el tamaño de las imágenes de entrada 

unet_input = Input(shape=input_shape, name='encoder_input')  # Tensor de entrada

# Aplicamos convoluciones traspuestas con stride=2 para reducir las dimensiones de los datos poco a poco
enc1 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(unet_input)

maxpool1 = MaxPooling2D((2, 2))(enc1)

enc2 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(maxpool1)

maxpool2 = MaxPooling2D((2, 2))(enc2)

enc3 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(maxpool2)

maxpool3 = MaxPooling2D((2, 2))(enc3)

enc4 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(maxpool3)

maxpool4 = MaxPooling2D((2, 2))(enc4)

huella_latente = Conv2D(filters=8,
                  kernel_size=3,
                  activation='relu',
                  strides=1,
                  padding='same')(maxpool4)

# %% [markdown]
# ### Decoder
#
# En este caso el decodificador ha de reconstruit una imagen con tamaño (128, 128, 1) que es la dimensión del ground thruth. Además, en U-Net se crean conexiones residuales entre las capas del mismo nivel del codificador y el decodificador mediante una concatenación.
#
# Es importante tener en cuenta que en este caso no se utilizan convolucones traspuestas y por lo tanto, usar un stride=2 no va a aumentar el tamaño de los vectores. Para realizar este paso, en el codificador se ha utilizado Max Pooling y en el decodificador se tendrá que usar una operación inversa que es Up Samplig.

# %%
# Contruir el decodificador

# Aplicamos convoluciones traspuestas con stride=2 hasta alcanzar la forma (128, 128, 8)
UpSamp1 = UpSampling2D((2,2))(huella_latente)
UpSamp1 = Concatenate()([UpSamp1, enc4])

dec1 = Conv2D(filters=8,
              kernel_size=3,
              activation='relu',
              strides=1,
              padding='same')(UpSamp1)

UpSamp2 = UpSampling2D((2,2))(dec1)
UpSamp2 = Concatenate()([UpSamp2, enc3])

dec2 = Conv2D(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=1,
                    padding='same')(UpSamp2)

UpSamp3 = UpSampling2D((2,2))(dec2)
UpSamp3 = Concatenate()([UpSamp3, enc2])

dec3 = Conv2D(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=1,
                    padding='same')(UpSamp3)

UpSamp4 = UpSampling2D((2,2))(dec3)
UpSamp4 = Concatenate()([UpSamp4, enc1])

dec4 = Conv2D(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=1,
                    padding='same')(UpSamp4)


# Transformamos el vector dec4 para que tenga el número de canales deseado
unet_output = Conv2DTranspose(filters=2,
                      kernel_size=1,
                      activation='linear',
                      padding='same',
                      name='decoder_output')(dec4)  # Activación sigmoide para que las salidas estén en rango [0, 1]

unet_output = tf.keras.activations.softmax(unet_output, axis=-1)

# %%
unet =  tf.keras.models.Model(unet_input, unet_output, name='U-Net')

# %%
# unet.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4),
#                     loss=tf.keras.losses.BinaryCrossentropy(),
#                     metrics=tf.keras.metrics.BinaryAccuracy(threshold=0.5))
unet.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4),
                    loss=tf.keras.losses.CategoricalCrossentropy(),
                    metrics=tf.keras.metrics.CategoricalAccuracy())

unet.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 8)  224         ['encoder_input[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 64, 64, 8)   0           ['conv2d_43[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 64, 64, 8)    584         ['max_pooling2d_12[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 32, 32, 8)   0           ['conv2d_44[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 8)    584         ['max_pooling2d_13[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 16, 16, 8)   0           ['conv2d_45[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 8)    584         ['max_pooling2d_14[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 8, 8, 8)     0           ['conv2d_46[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 8)      584         ['max_pooling2d_15[0][0]']
#
#  up_sampling2d_16 (UpSampling2D  (None, 16, 16, 8)   0           ['conv2d_47[0][0]']
#  )
#
#  concatenate_16 (Concatenate)   (None, 16, 16, 16)   0           ['up_sampling2d_16[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 8)    1160        ['concatenate_16[0][0]']
#
#  up_sampling2d_17 (UpSampling2D  (None, 32, 32, 8)   0           ['conv2d_48[0][0]']
#  )
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 16)   0           ['up_sampling2d_17[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 8)    1160        ['concatenate_17[0][0]']
#
#  up_sampling2d_18 (UpSampling2D  (None, 64, 64, 8)   0           ['conv2d_49[0][0]']
#  )
#
#  concatenate_18 (Concatenate)   (None, 64, 64, 16)   0           ['up_sampling2d_18[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 8)    1160        ['concatenate_18[0][0]']
#
#  up_sampling2d_19 (UpSampling2D  (None, 128, 128, 8)  0          ['conv2d_50[0][0]']
#  )
#
#  concatenate_19 (Concatenate)   (None, 128, 128, 16  0           ['up_sampling2d_19[0][0]',
#                                 )                                 'conv2d_43[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 8)  1160        ['concatenate_19[0][0]']
#
#  decoder_output (Conv2DTranspos  (None, 128, 128, 2)  18         ['conv2d_51[0][0]']
#  e)
#
#  tf.nn.softmax_2 (TFOpLambda)   (None, 128, 128, 2)  0           ['decoder_output[0][0]']
#
# ==================================================================================================
# Total params: 7,218
# Trainable params: 7,218
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# ## Entrenar U-Net

# %%
batch_size = 8
epochs = 50

unet.fit(x_train, y_train_unet, epochs=epochs, batch_size=batch_size, shuffle=True, validation_data=(x_val, y_val_unet))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 4s 286ms/step - loss: 0.7447 - categorical_accuracy: 0.2854 - val_loss: 0.6693 - val_categorical_accuracy: 0.7206
# Epoch 2/50
# 11/11 [==============================] - 3s 256ms/step - loss: 0.7058 - categorical_accuracy: 0.3490 - val_loss: 0.7028 - val_categorical_accuracy: 0.3122
# Epoch 3/50
# 11/11 [==============================] - 3s 262ms/step - loss: 0.6720 - categorical_accuracy: 0.7197 - val_loss: 0.7399 - val_categorical_accuracy: 0.2702
# Epoch 4/50
# 11/11 [==============================] - 3s 257ms/step - loss: 0.6420 - categorical_accuracy: 0.7223 - val_loss: 0.7815 - val_categorical_accuracy: 0.2789
# Epoch 5/50
# 11/11 [==============================] - 3s 259ms/step - loss: 0.6142 - categorical_accuracy: 0.7185 - val_loss: 0.8282 - val_categorical_accuracy: 0.2788
# Epoch 6/50
# 11/11 [==============================] - 3s 262ms/step - loss: 0.5874 - categorical_accuracy: 0.7236 - val_loss: 0.8758 - val_categorical_accuracy: 0.2783
# Epoch 7/50
# 11/11 [==============================] - 3s 261ms/step - loss: 0.5650 - categorical_accuracy: 0.7192 - val_loss: 0.9311 - val_categorical_accuracy: 0.2785
# Epoch 8/50
# 11/11 [==============================] - 3s 261ms/step - loss: 0.5458 - categorical_accuracy: 0.7194 - val_loss: 0.9896 - val_categorical_accuracy: 0.2805
# Epoch 9/50
# 11/11 [==============================] - 3s 259ms/step - loss: 0.5283 - categorical_accuracy: 0.7193 - val_loss: 1.0482 - val_categorical_accuracy: 0.2769
# Epoch 10/50
# 11/11 [==============================] - 3s 263ms/step - loss: 0.5116 - categorical_accuracy: 0.7261 - val_loss: 1.1010 - val_categorical_accuracy: 0.2650
# Epoch 11/50
# 11/11 [==============================] - 3s 262ms/step - loss: 0.4929 - categorical_accuracy: 0.7440 - val_loss: 1.1471 - val_categorical_accuracy: 0.2408
# Epoch 12/50
# 11/11 [==============================] - 3s 260ms/step - loss: 0.4686 - categorical_accuracy: 0.7729 - val_loss: 1.1915 - val_categorical_accuracy: 0.2077
# Epoch 13/50
# 11/11 [==============================] - 3s 261ms/step - loss: 0.4374 - categorical_accuracy: 0.8033 - val_loss: 1.2989 - val_categorical_accuracy: 0.1823
# Epoch 14/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.3957 - categorical_accuracy: 0.8374 - val_loss: 1.4246 - val_categorical_accuracy: 0.1398
# Epoch 15/50
# 11/11 [==============================] - 3s 261ms/step - loss: 0.3455 - categorical_accuracy: 0.8759 - val_loss: 1.6273 - val_categorical_accuracy: 0.1049
# Epoch 16/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.2906 - categorical_accuracy: 0.9021 - val_loss: 1.9455 - val_categorical_accuracy: 0.0934
# Epoch 17/50
# 11/11 [==============================] - 3s 262ms/step - loss: 0.2386 - categorical_accuracy: 0.9157 - val_loss: 2.2983 - val_categorical_accuracy: 0.0764
# Epoch 18/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.1951 - categorical_accuracy: 0.9286 - val_loss: 2.7294 - val_categorical_accuracy: 0.0647
# Epoch 19/50
# 11/11 [==============================] - 3s 263ms/step - loss: 0.1625 - categorical_accuracy: 0.9381 - val_loss: 3.2384 - val_categorical_accuracy: 0.0554
# Epoch 20/50
# 11/11 [==============================] - 3s 263ms/step - loss: 0.1388 - categorical_accuracy: 0.9457 - val_loss: 3.6705 - val_categorical_accuracy: 0.0483
# Epoch 21/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.1220 - categorical_accuracy: 0.9525 - val_loss: 4.0325 - val_categorical_accuracy: 0.0421
# Epoch 22/50
# 11/11 [==============================] - 3s 261ms/step - loss: 0.1097 - categorical_accuracy: 0.9578 - val_loss: 4.3262 - val_categorical_accuracy: 0.0380
# Epoch 23/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.1000 - categorical_accuracy: 0.9621 - val_loss: 4.6121 - val_categorical_accuracy: 0.0344
# Epoch 24/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0927 - categorical_accuracy: 0.9651 - val_loss: 4.8166 - val_categorical_accuracy: 0.0325
# Epoch 25/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0863 - categorical_accuracy: 0.9678 - val_loss: 5.0952 - val_categorical_accuracy: 0.0292
# Epoch 26/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0817 - categorical_accuracy: 0.9696 - val_loss: 5.2928 - val_categorical_accuracy: 0.0273
# Epoch 27/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0767 - categorical_accuracy: 0.9717 - val_loss: 5.5197 - val_categorical_accuracy: 0.0261
# Epoch 28/50
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0730 - categorical_accuracy: 0.9730 - val_loss: 5.6598 - val_categorical_accuracy: 0.0248
# Epoch 29/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0704 - categorical_accuracy: 0.9740 - val_loss: 5.8584 - val_categorical_accuracy: 0.0236
# Epoch 30/50
# 11/11 [==============================] - 3s 263ms/step - loss: 0.0671 - categorical_accuracy: 0.9751 - val_loss: 5.9940 - val_categorical_accuracy: 0.0232
# Epoch 31/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0639 - categorical_accuracy: 0.9763 - val_loss: 6.2522 - val_categorical_accuracy: 0.0214
# Epoch 32/50
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0611 - categorical_accuracy: 0.9774 - val_loss: 6.3816 - val_categorical_accuracy: 0.0209
# Epoch 33/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.0592 - categorical_accuracy: 0.9780 - val_loss: 6.4984 - val_categorical_accuracy: 0.0206
# Epoch 34/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0567 - categorical_accuracy: 0.9792 - val_loss: 6.6886 - val_categorical_accuracy: 0.0191
# Epoch 35/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.0547 - categorical_accuracy: 0.9800 - val_loss: 6.8492 - val_categorical_accuracy: 0.0185
# Epoch 36/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0537 - categorical_accuracy: 0.9802 - val_loss: 7.0172 - val_categorical_accuracy: 0.0182
# Epoch 37/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0517 - categorical_accuracy: 0.9811 - val_loss: 7.1012 - val_categorical_accuracy: 0.0179
# Epoch 38/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0502 - categorical_accuracy: 0.9818 - val_loss: 7.2717 - val_categorical_accuracy: 0.0167
# Epoch 39/50
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0505 - categorical_accuracy: 0.9812 - val_loss: 7.3624 - val_categorical_accuracy: 0.0170
# Epoch 40/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0491 - categorical_accuracy: 0.9819 - val_loss: 7.5281 - val_categorical_accuracy: 0.0163
# Epoch 41/50
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0467 - categorical_accuracy: 0.9831 - val_loss: 7.6154 - val_categorical_accuracy: 0.0155
# Epoch 42/50
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0453 - categorical_accuracy: 0.9835 - val_loss: 7.7011 - val_categorical_accuracy: 0.0158
# Epoch 43/50
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0450 - categorical_accuracy: 0.9836 - val_loss: 7.8513 - val_categorical_accuracy: 0.0149
# Epoch 44/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0436 - categorical_accuracy: 0.9842 - val_loss: 7.9327 - val_categorical_accuracy: 0.0146
# Epoch 45/50
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0431 - categorical_accuracy: 0.9843 - val_loss: 8.0485 - val_categorical_accuracy: 0.0141
# Epoch 46/50
# 11/11 [==============================] - 3s 270ms/step - loss: 0.0418 - categorical_accuracy: 0.9848 - val_loss: 8.1790 - val_categorical_accuracy: 0.0141
# Epoch 47/50
# 11/11 [==============================] - 3s 272ms/step - loss: 0.0411 - categorical_accuracy: 0.9851 - val_loss: 8.2615 - val_categorical_accuracy: 0.0135
# Epoch 48/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0406 - categorical_accuracy: 0.9852 - val_loss: 8.3411 - val_categorical_accuracy: 0.0133
# Epoch 49/50
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0396 - categorical_accuracy: 0.9857 - val_loss: 8.4761 - val_categorical_accuracy: 0.0134
# Epoch 50/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0396 - categorical_accuracy: 0.9856 - val_loss: 8.5023 - val_categorical_accuracy: 0.0142

# %% [markdown]
# ## Testing U-Net
# Vamos a pasar la red sobre el conjunto de test para ver si ha
# generalizado.

# %% [markdown]
# La función evaluate realiza un predict sobre cada entrada del conjunto de test y extrae las métricas que hayamos indicado al compilar el modelo.

# %%
unet.evaluate(x_test, y_test_unet, batch_size=batch_size)
# Out:
# 13/13 [==============================] - 1s 95ms/step - loss: 0.5430 - categorical_accuracy: 0.8929
# [0.542988121509552, 0.8928772211074829]

# %% [markdown]
# Por último, vamos a visualizar algunos de los resultados.
#
# La siguiente celda selecciona varias imágenes aleatorias y muestra su salida.

# %%
# Selecionamos varias imágenes aleatorias del conjunto de test
examples_index = np.random.choice(x_test.shape[0], figsize*2)
examples = x_test[examples_index]

# Realizamos la predicción con el autoencoder
predictions = unet.predict(examples)

predictions = np.argmax(predictions, axis=-1)  # (n, 128, 128)

# Preparamos la figura de matplotlib
figsize = 5
num_examples_to_generate = figsize*figsize

fig = plt.figure()
fig.suptitle('Resultados segmentación')

for i in range(figsize*2):

    plt.subplot(4, figsize, i+1)
    plt.imshow(examples[i])
    plt.subplot(4, figsize, i + 1 + figsize*2)
    plt.imshow(predictions[i], cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# A continuación vamos a realizar una visualización de los mapas de probabilidad generado para cada máscara

# %%
# Selecionamos varias imágenes aleatorias del conjunto de test
examples_index = np.random.choice(x_test.shape[0], 2)
examples = x_test[examples_index]

# Realizamos la predicción con el autoencoder
predictions = unet.predict(examples)

predictions_bg = predictions[:, :, :, 0]
predictions_fg = predictions[:, :, :, 1]

# Preparamos la figura de matplotlib
num_examples_to_generate = figsize*figsize

fig = plt.figure()

plt.subplot(2, 3, 1)  #, title='Original')
plt.imshow(examples[0])

plt.subplot(2, 3, 2)
plt.imshow(predictions_fg[0], cmap='gray')

plt.subplot(2, 3, 3)
plt.imshow(predictions_bg[0], cmap='gray')

plt.subplot(2, 3, 4)
plt.imshow(examples[1])

plt.subplot(2, 3, 5)
plt.imshow(predictions_fg[1], cmap='gray')

plt.subplot(2, 3, 6)
plt.imshow(predictions_bg[1], cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# # Otros recursos
# A continuación os dejamos algunos recursos con información sobre plataformas de cómputo para Deep Learning como Tensorflow, keras y pytorch.
#
# También teneis algunos enlaces a datasets de segmentación pequeños que se pueden utilizar para talleres y pruebas y a sitios web donde podeis encontrar otros datasets.

# %% [markdown]
# ## Recursos y tutoriales
#
# TensorFlow (TF2): https://www.tensorflow.org/
#
# Keras: https://keras.io/
#
# *   Tutoriales TF2: https://www.tensorflow.org/tutorials
#   *   Segmentación: https://www.tensorflow.org/tutorials/images/segmentation
#   *   Autoencoder variacional: https://www.tensorflow.org/tutorials/generative/cvae
# *   Tutoriales keras: https://keras.io/examples/
#   *   Segmentación con U-Net: https://keras.io/examples/vision/oxford_pets_image_segmentation/
#   *   Autoencoder para denoising: https://keras.io/examples/vision/autoencoder/
#   *   Segementación con DeepLabV3+: https://keras.io/examples/vision/deeplabv3_plus/

# %% [markdown]
# ## Datasets
#
# * Datasets interesantes para realizar pequeñas pruebas
#   * ConferenceVideoSegmentationDataset: https://github.com/kuangzijian/Flow-Based-Video-Segmentation
#     * Data url: https://drive.google.com/file/d/13JKwoCaoSWQAjJ1YLVfV6AHvm8by09fP/view
#     * Cuatro videos estilo conferencia con segmentaciones de las personas.
#     * Dataset creado semi artificialmente utilizando una pantalla verde de fondo
#
#   * The Oxford-IIIT Pet Dataset: https://www.robots.ox.ac.uk/~vgg/data/pets/
#     * 36 tipos de máscotas segmentadas con 200 imágenes por tipo
#     * Anotaciones de backgroud, edges y foreground.
#
# * Colecciones de datasets:
#   * Papers with Code: https://paperswithcode.com/datasets?q=segmentation&v=lst&o=match&page=1
#   * Kaggle: https://www.kaggle.com/datasets
#   * UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/index.php
#   * Google Dataset Search: https://datasetsearch.research.google.com/
#   * Visual Data: https://visualdata.io/discovery

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Kingma, D. P., & Welling, M. (2013). Auto-encoding variational bayes.

# %% [markdown]
# Finalmente podemos crear diferentes arquitecturas de red para solucionar problemas específicos. En este caso de autoencoder variacional no solo se realiza una segmentación semántica, si no que además se extrae una imagen de profundidad y se reconstruye la imagen real.
#
# ![3VAE.png](data:image/png;base64,...)
#
# Hernández-García S., Cuesta-Infante A. (2021) Deep Reinforcement and Imitation Learning for Self-driving Tasks. In: Alba E. et al. (eds) Advances in Artificial Intelligence. CAEPIA 2021. Lecture Notes in Computer Science, vol 12882. Springer, Cham. https://doi.org/10.1007/978-3-030-85713-4_7
