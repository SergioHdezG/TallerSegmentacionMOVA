# %% [markdown]
# # Taller de segmentación de imágenes
#
# La segementación semántica sobre imágenes consiste en, dada una imagen, determinar a que objeto de esa imagen corresponde cada pixel. Específicamente, consiste en un problema denso de clasificación de imágenes, es decir, en lugar de determinar a que clase corresponde una imagen completa, queremos determinar la clase de cada lugar de la imagen obteniendo así otras propiedades de los objetos como forma o tamaño.

# %% [markdown]
# ![1](https://www.cityscapes-dataset.com/wordpress/wp-content/uploads/2015/07/koeln00.png)

# %% [markdown]
# # Arquitecturas neuronales para segmentación
#
# La arquitectura de red más comunmente utilizada para realizar la tarea de segmentación sobre imágenes es la de los Autoencoder y existen multiples tipos y versiones. A continuación enumeramos algunos:
# - Autoencoders (AEs)
# - U-Net
# - V-Net - Se trabaja con volúmenes
# - Autoencoder Variacional (VAE)

# %% [markdown]
# # Autoencoder (AE)
#
# El Autoencoder (AE) es la primera de las versiones, la más básica y de la que parten el resto de tipos de autoencoder.
#
# Consiste en una red neuronal, ya sea densa o convolucional, que presenta un cuello de botella. La función de este cuello de botella es reducir las dimensiones (comprimir) de los datos de entrada a un vector de pequeñas dimensiones que se conoce con el nombre de **huella latente**.
#
# Se compone de dos partes principales:
# - **Codificador:** Red neuronal que comprime los datos de entrada en la huella latente.
# - **Decodificador:** Red neuronal que transforma la huella latente en un vector de grandes dimensiones que puede ser: los datos originales reconstruidos o una transformación de estos (Imagen de profundidas, flujo óptico, segmentación, etc)
#
# ![AE](https://raw.githubusercontent.com/SergioHdezG/TallerSegmentacionMUVA/master/imagenes/AE.png)
#
# KRAMER, Mark A. Nonlinear principal component analysis using autoassociative neural networks. AIChE journal, 1991, vol. 37, no 2, p. 233-243.  https://doi.org/10.1002/aic.690370209

# %% [markdown]
# # Ejemplo práctico de Autoencoder
# A continuación comenzamos la parte de implementación de este taller para aprender como construir un autoencoder en Keras.
#
# ## Recursos
#
# En este notebook utilizamos la librería de cómputo Tensorflow (TF) y específicamente su módulo para deep learning Keras
#
# TensorFlow (TF2): https://www.tensorflow.org/
#
# Keras: https://keras.io/
#
# Como dataset se va a utilizar el Conference Video Segmentation Dataset (https://github.com/kuangzijian/Flow-Based-Video-Segmentation):
#
#   * Data url: https://drive.google.com/file/d/13JKwoCaoSWQAjJ1YLVfV6AHvm8by09fP/view
#   * Cuatro videos estilo conferencia con segmentación de las personas.
#   * Dataset creado semi artificialmente utilizando una pantalla verde de fondo.
#
# Input:
#
# ![Input Image](https://raw.githubusercontent.com/kuangzijian/Flow-Based-Video-Segmentation/master/readme_imgs/with_bg.jpg)
#
# Ground truth:
#
# ![Ground truth](https://raw.githubusercontent.com/kuangzijian/Flow-Based-Video-Segmentation/master/readme_imgs/ground_truth.jpg)

# %% [markdown]
# ## Carga y preprocesado de datos
#
# El primer paso para resolver cualquier problema de machine learning es cargar, visualizar y preprocesar el conjunto de datos que se va a utilizar.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras import backend as K

import os
#import cv2
import numpy as np
from matplotlib import image as plt_image
import matplotlib.pyplot as plt
# Out:
# 2022-12-14 13:48:57.804705: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shernandez/.mujoco/mujoco210/bin:/usr/lib/nvidia
# 2022-12-14 13:48:57.804722: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# La siguiente celda solo es necesario ejecutarla si estás en google colab, si estás en binder omitela y omite el enlace al dataset.
#
# El dataset se encuentra en: https://drive.google.com/file/d/1ChXfmym3HinaQ_3Bg37xQdUleaFb5F70/view?usp=sharing
#
# Añadelo a tu google drive

# %%
""" from google.colab import drive 
 drive.mount('/content/drive')"""
# Out:
# " from google.colab import drive \n drive.mount('/content/drive')"

# %% [markdown]
# El dataset se encuentra comprimido, hay que descomprimirlo.
# En la siguiente instrucción escribe la ruta al archivo y la carpeta de destino

# %%
# !unzip -u "datasets/ConferenceMinidataset.zip" -d "carpeta_destino"
# Out:
# Archive:  datasets/ConferenceMinidataset.zip

# %% [markdown]
# Cargamos los nombres de los ficheros en memoria y ordenamos los datos para que coincidan las imágenes de entrada con las máscaras de segmentación.

# %%
data_path = "../../carpeta_destino/ConferenceMinidataset"
training_in = os.listdir(os.path.join(data_path, "original_training"))
training_label = os.listdir(os.path.join(data_path, "ground_truth_training"))

# Ordenamos las imágenes por sequencia de video y por fotograma (original"seq"_"ft".jpg//gt"seq"_"ft".jpg)
training_in.sort(key= lambda x : (int(x.split("_")[0].split("l")[1]), int(x.split(".")[0].split("_")[1])))
training_label.sort(key= lambda x : (int(x.split("_")[0].split("t")[1]), int(x.split(".")[0].split("_")[1])))

print('Training size: ', len(training_in))
print(training_in[:10])
print(training_label[:10])
# Out:
# Training size:  1326
# ['original1_1.jpg', 'original1_2.jpg', 'original1_3.jpg', 'original1_4.jpg', 'original1_5.jpg', 'original1_6.jpg', 'original1_7.jpg', 'original1_8.jpg', 'original1_9.jpg', 'original1_10.jpg']
# ['gt1_1.jpg', 'gt1_2.jpg', 'gt1_3.jpg', 'gt1_4.jpg', 'gt1_5.jpg', 'gt1_6.jpg', 'gt1_7.jpg', 'gt1_8.jpg', 'gt1_9.jpg', 'gt1_10.jpg']

# %% [markdown]
# Cargamos los datos de entrenamiento en un numpy array.
#
# En este ejemplo se cargan solo las 100 primeras imágenes.

# %%
x_train = [plt_image.imread(os.path.join(data_path, "original_training", name)) for name in training_in[:100]]
y_train = [plt_image.imread(os.path.join(data_path, "ground_truth_training", name)) for name in training_label[:100]]
print('Training size: ', len(x_train))
# Out:
# Training size:  100

# %% [markdown]
# En este ejemplo hemos preparado previamente los datos para que cada imagen tenga tamaño (128, 128). El dataset original contenía imágenes de dimensiones  (360, 640) que era necesario modificar por tres motivos:
#
#
# 1.   Para ajustarlos al tamaño de entrada que nos interesa en la red neuronal
# 2.   Para que al realizar convoluciones con stride=2 o Max Pooling no quede ninguna dimensión impar. Si se diese ese caso luego tendríamos problemas para recuperar el tamaño original a la salida del autoencoder.
# 3.   Para simplificar y acelerar el procesamiento a efectos prácticos de este taller.
#
# La siguiente celda muestra un código de ejemplo para redimensionar las imágenes del dataset que no es necesario ejecutar.

# %%
"""import cv2
for i in range(len(x_train)):
    x_train[i] = cv2.resize(x_train[i], (128, 128))
    y_train[i] = cv2.resize(y_train[i], (128, 128))"""
# Out:
# 'import cv2\nfor i in range(len(x_train)):\n    x_train[i] = cv2.resize(x_train[i], (128, 128))\n    y_train[i] = cv2.resize(y_train[i], (128, 128))'

# %% [markdown]
# Realizamos una visualización de los datos contenidos en el dataset.

# %%
n_img = np.random.randint(0, len(x_train))
img_in = x_train[n_img]
img_label = y_train[n_img]

print('Input image shape: ', img_in.shape)
print('Label image shape: ', img_label.shape)

plt.figure(figsize=(7,7))
plt.subplot(2, 2, 1)
plt.imshow(img_in)

plt.subplot(2, 2, 2)
plt.imshow(img_label)

n_img = np.random.randint(0, len(x_train))
img_in = x_train[n_img]
img_label = y_train[n_img]

plt.subplot(2, 2, 3)
plt.imshow(img_in)

plt.subplot(2, 2, 4)
plt.imshow(img_label)

plt.show()

print("Train images range: : [", np.amin(img_in), ", ", np.amax(img_in), "]")
print("Test images range: : [", np.amin(img_label), ",", np.amax(img_label), "]")
# Out:
# Input image shape:  (128, 128, 3)
# Label image shape:  (128, 128, 3)
# Train images range: : [ 0 ,  255 ]
# Test images range: : [ 0 , 255 ]

# %% [markdown]
# Como se puede observar en la celda anterior, los datos se encuentran en el rango de valores [0, 255]. Nos interesa normalizarlos al rango [0, 1] y convertirlos a tipo float32.
#
# Posteriormente nos quedamos solo con uno de los tres canales de las imágenes segmentadas ya que se encuentran triplicados.

# %%
# Normalizamos los datos de entrada en rango [0, 1]
x_train = np.array(x_train, dtype=np.float32) / 255.
y_train = np.array(y_train, dtype=np.float32) / 255.

# Nos quedamos solo con el primer canal de las etiquetas
y_train = np.expand_dims(y_train[:, :, :, 0], axis=-1)

print('Input image shape: ', x_train[0].shape)
print('Label image shape: ', y_train[0].shape)

print("Train images range: : [", np.amin([x_train[0]]), ", ", np.amax(x_train[0]), "]")
print("Test images range: : [", np.amin(y_train[0]), ",", np.amax(y_train[0]), "]")
# Out:
# Input image shape:  (128, 128, 3)
# Label image shape:  (128, 128, 1)
# Train images range: : [ 0.0 ,  1.0 ]
# Test images range: : [ 0.0 , 1.0 ]

# %% [markdown]
# Separamos un subconjunto de los datos para hacer validación.

# %%
# separamos un subconjunto de validación

val_split = 0.15
val_split = int(x_train.shape[0] * val_split)
val_idx = np.random.choice(x_train.shape[0], val_split, replace=False)  # Seleccionamos varios índices aleatorios
train_mask = np.array([False if i in val_idx else True for i in range(x_train.shape[0])])  # Creamos una máscara para seleccionar los datos de entrenamiento

x_val = x_train[val_idx]  # Seleccionamos datos de validacón
y_val = y_train[val_idx]

x_train = x_train[train_mask]  # Seleccionamos datos de entrenamiento
y_train = y_train[train_mask]

print('Train samples: ', x_train.shape[0])
print('Validation samples: ', x_val.shape[0])
# Out:
# Train samples:  85
# Validation samples:  15

# %% [markdown]
# ## Contruir el Autoencoder
# Para la creación del Autoencoder se va a seguir la siguiente arquitectura:

# %% [markdown]
# ![Autoencoder.png](data:image/png;base64,...)

# %% [markdown]
# ### Encoder:
#
# Documentación funciones de activación: https://www.tensorflow.org/api_docs/python/tf/keras/activations

# %%
# Construir el codificador

input_shape = (128, 128, 3) # Definimos el tamaño de las imágenes de entrada
latent_dim = 256 # Tamaño de la huella latente

encoder_input = Input(shape=input_shape, name='encoder_input')  # Tensor de entrada

# Aplicamos convoluciones con xxxxx para reducir las dimensiones de los datos poco a poco
enc1 = Conv2D(filters=8,
            kernel_size= 3,
            activation= 'relu',
            strides= 2,
            padding='same')(encoder_input)

enc2 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=2,
            padding='same')(enc1)

enc3 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=2,
            padding='same')(enc2)

enc4 = Conv2D(filters=16,
            kernel_size=3,
            activation='relu',
            strides=2,
            padding='same')(enc3)

enc5 = Flatten()(enc4)

# Vector latente de dimensión latent_dim  
huella_latente = Dense(latent_dim, activation='linear', name='latent')(enc5)
# Out:
# 2022-12-14 13:48:59.501362: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 13:48:59.501703: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shernandez/.mujoco/mujoco210/bin:/usr/lib/nvidia
# 2022-12-14 13:48:59.501756: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shernandez/.mujoco/mujoco210/bin:/usr/lib/nvidia
# 2022-12-14 13:48:59.501806: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shernandez/.mujoco/mujoco210/bin:/usr/lib/nvidia
# 2022-12-14 13:48:59.502833: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shernandez/.mujoco/mujoco210/bin:/usr/lib/nvidia
# 2022-12-14 13:48:59.502883: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shernandez/.mujoco/mujoco210/bin:/usr/lib/nvidia
# 2022-12-14 13:48:59.502936: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shernandez/.mujoco/mujoco210/bin:/usr/lib/nvidia
# 2022-12-14 13:48:59.502945: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1835] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-12-14 13:48:59.503146: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Decoder

# %% [markdown]
# A la hora de construir el decodificador hay que prestar especial atención a las dimensiones de los datos ya que queremos reconstruir una imagen del mismo tamaño que la original.
#
# El tamaño de entrada de nuestra red es (128, 128, 3), en la salida de la última capa convoluconal el tamaño de los datos es  (8, 8, 16).y el tamaño de la huella latente es 256.
#
# Al construir el decodificador hay que hacer el camino inverso. En este caso, convertiremos la huella latente en un vector de 1024 valores que daremos forma de imagen (8, 8, 16) con una capa Reshape. Una vez tenemos una imagen de la misma dimensión que la de la capa enc4 solo tenemos que deshacer los pasos utilizando convoluciones traspuestas. Finalmente, se obtiene una imagen de tamaño (128, 128, 8) que se procesará por una última capa con el número de filtros igual al número de canales de la imagen objetivo (en este caso uno) (128, 128, 1).
#
# Una convolución transpuesta permite aplicar un kernel sobre una matriz y obtener una matriz resultante de tamaño mayor. [What is Transposed Convolutional Layer?](https://towardsdatascience.com/what-is-transposed-convolutional-layer-40e5e6e31c11)
#
# ![Convolución traspuesta](https://raw.githubusercontent.com/SergioHdezG/TallerSegmentacionMUVA/2022/imagenes/TrasposedConvolutions.gif)
# ![Convolución traspuesta stride=2](https://raw.githubusercontent.com/SergioHdezG/TallerSegmentacionMUVA/2022/imagenes/TrasposedConvolutions2.gif)

# %%
# Contruir el decodificador

enc4_shape = K.int_shape(enc4)  # Forma del vector enc4

# Esta capa densa transforma la huella latente en un vector con el mismo número de píxeles que la salida de la capa enc4
dec = Dense(enc4_shape[1] * enc4_shape[2] * enc4_shape[3], activation='relu')(huella_latente)

# Transformamos el vector dec y le damos forma de imagen
dec1 = Reshape((enc4_shape[1], enc4_shape[2], enc4_shape[3]))(dec)

# Aplicamos convoluciones traspuestas con xxx hasta alcanzar la forma (128, 128, 8)
dec2 = Conv2DTranspose(filters=16,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec1)

dec3 = Conv2DTranspose(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec2)

dec4 = Conv2DTranspose(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec3)

dec5 = Conv2DTranspose(filters=8,
                    kernel_size=3,
                    activation='relu',
                    strides=2,
                    padding='same')(dec4)

# Transformamos el vector dec5 para que tenga el número de canales deseado
decoder_output = Conv2DTranspose(filters=1,
                      kernel_size=3,
                      activation='sigmoid',
                      padding='same',
                      name='decoder_output')(dec5)  # Activación xxxx para que las salidas estén en rango [0, 1]

# %% [markdown]
# Construimos y compilamos el modelo en keras

# %%
autoencoder =  tf.keras.models.Model(encoder_input, decoder_output, name='AE')

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                    loss=tf.keras.losses.BinaryCrossentropy(),
                    metrics=tf.keras.metrics.BinaryAccuracy(threshold=0.5))

autoencoder.summary()
# Out:
# Model: "AE"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 8)         224
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 8)         584
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 8)         584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 16)          1168
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# latent (Dense)               (None, 256)               262400
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 8)         1160
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 64, 64, 8)         584
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 128, 128, 8)       584
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 1)       73
# =================================================================
# Total params: 532,849
# Trainable params: 532,849
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento

# %%
batch_size = 8
epochs = 50

autoencoder.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, shuffle=True, validation_data=(x_val, y_val))
# Out:
# 2022-12-14 13:48:59.833758: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 11/11 [==============================] - 1s 35ms/step - loss: 0.6927 - binary_accuracy: 0.6208 - val_loss: 0.6922 - val_binary_accuracy: 0.6594
# Epoch 2/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6917 - binary_accuracy: 0.6611 - val_loss: 0.6911 - val_binary_accuracy: 0.6621
# Epoch 3/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6904 - binary_accuracy: 0.6609 - val_loss: 0.6895 - val_binary_accuracy: 0.6593
# Epoch 4/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6883 - binary_accuracy: 0.6552 - val_loss: 0.6863 - val_binary_accuracy: 0.6492
# Epoch 5/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6835 - binary_accuracy: 0.6422 - val_loss: 0.6783 - val_binary_accuracy: 0.6343
# Epoch 6/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6708 - binary_accuracy: 0.6306 - val_loss: 0.6572 - val_binary_accuracy: 0.6290
# Epoch 7/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.6384 - binary_accuracy: 0.6321 - val_loss: 0.6058 - val_binary_accuracy: 0.6378
# Epoch 8/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.5679 - binary_accuracy: 0.6434 - val_loss: 0.5099 - val_binary_accuracy: 0.6502
# Epoch 9/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4643 - binary_accuracy: 0.6548 - val_loss: 0.4098 - val_binary_accuracy: 0.6595
# Epoch 10/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3889 - binary_accuracy: 0.6612 - val_loss: 0.3618 - val_binary_accuracy: 0.6630
# Epoch 11/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.3539 - binary_accuracy: 0.6629 - val_loss: 0.3353 - val_binary_accuracy: 0.6634
# Epoch 12/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3301 - binary_accuracy: 0.6630 - val_loss: 0.3162 - val_binary_accuracy: 0.6634
# Epoch 13/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3131 - binary_accuracy: 0.6628 - val_loss: 0.3024 - val_binary_accuracy: 0.6631
# Epoch 14/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3005 - binary_accuracy: 0.6629 - val_loss: 0.2918 - val_binary_accuracy: 0.6635
# Epoch 15/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2908 - binary_accuracy: 0.6632 - val_loss: 0.2835 - val_binary_accuracy: 0.6637
# Epoch 16/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2837 - binary_accuracy: 0.6635 - val_loss: 0.2774 - val_binary_accuracy: 0.6641
# Epoch 17/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.2784 - binary_accuracy: 0.6640 - val_loss: 0.2730 - val_binary_accuracy: 0.6647
# Epoch 18/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2745 - binary_accuracy: 0.6643 - val_loss: 0.2698 - val_binary_accuracy: 0.6647
# Epoch 19/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2718 - binary_accuracy: 0.6644 - val_loss: 0.2672 - val_binary_accuracy: 0.6650
# Epoch 20/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2696 - binary_accuracy: 0.6647 - val_loss: 0.2654 - val_binary_accuracy: 0.6654
# Epoch 21/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2679 - binary_accuracy: 0.7803 - val_loss: 0.2639 - val_binary_accuracy: 0.8511
# Epoch 22/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2666 - binary_accuracy: 0.8504 - val_loss: 0.2627 - val_binary_accuracy: 0.8522
# Epoch 23/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2654 - binary_accuracy: 0.8517 - val_loss: 0.2616 - val_binary_accuracy: 0.8538
# Epoch 24/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2643 - binary_accuracy: 0.8530 - val_loss: 0.2605 - val_binary_accuracy: 0.8549
# Epoch 25/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2634 - binary_accuracy: 0.8536 - val_loss: 0.2595 - val_binary_accuracy: 0.8555
# Epoch 26/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2625 - binary_accuracy: 0.8550 - val_loss: 0.2587 - val_binary_accuracy: 0.8569
# Epoch 27/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2616 - binary_accuracy: 0.8561 - val_loss: 0.2580 - val_binary_accuracy: 0.8584
# Epoch 28/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2609 - binary_accuracy: 0.8575 - val_loss: 0.2571 - val_binary_accuracy: 0.8597
# Epoch 29/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2601 - binary_accuracy: 0.8588 - val_loss: 0.2564 - val_binary_accuracy: 0.8609
# Epoch 30/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2595 - binary_accuracy: 0.8603 - val_loss: 0.2556 - val_binary_accuracy: 0.8624
# Epoch 31/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2588 - binary_accuracy: 0.8613 - val_loss: 0.2551 - val_binary_accuracy: 0.8644
# Epoch 32/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2582 - binary_accuracy: 0.8631 - val_loss: 0.2546 - val_binary_accuracy: 0.8656
# Epoch 33/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2576 - binary_accuracy: 0.8644 - val_loss: 0.2539 - val_binary_accuracy: 0.8672
# Epoch 34/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2571 - binary_accuracy: 0.8658 - val_loss: 0.2533 - val_binary_accuracy: 0.8690
# Epoch 35/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2565 - binary_accuracy: 0.8674 - val_loss: 0.2529 - val_binary_accuracy: 0.8704
# Epoch 36/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2560 - binary_accuracy: 0.8691 - val_loss: 0.2526 - val_binary_accuracy: 0.8719
# Epoch 37/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2556 - binary_accuracy: 0.8705 - val_loss: 0.2521 - val_binary_accuracy: 0.8735
# Epoch 38/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2551 - binary_accuracy: 0.8720 - val_loss: 0.2516 - val_binary_accuracy: 0.8749
# Epoch 39/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2546 - binary_accuracy: 0.8738 - val_loss: 0.2512 - val_binary_accuracy: 0.8767
# Epoch 40/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.2542 - binary_accuracy: 0.8751 - val_loss: 0.2506 - val_binary_accuracy: 0.8784
# Epoch 41/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2537 - binary_accuracy: 0.8769 - val_loss: 0.2501 - val_binary_accuracy: 0.8796
# Epoch 42/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2533 - binary_accuracy: 0.8786 - val_loss: 0.2498 - val_binary_accuracy: 0.8815
# Epoch 43/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.2529 - binary_accuracy: 0.8799 - val_loss: 0.2494 - val_binary_accuracy: 0.8828
# Epoch 44/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2525 - binary_accuracy: 0.8814 - val_loss: 0.2491 - val_binary_accuracy: 0.8844
# Epoch 45/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2521 - binary_accuracy: 0.8827 - val_loss: 0.2487 - val_binary_accuracy: 0.8860
# Epoch 46/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2517 - binary_accuracy: 0.8840 - val_loss: 0.2482 - val_binary_accuracy: 0.8868
# Epoch 47/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.2514 - binary_accuracy: 0.8847 - val_loss: 0.2479 - val_binary_accuracy: 0.8875
# Epoch 48/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2510 - binary_accuracy: 0.8859 - val_loss: 0.2476 - val_binary_accuracy: 0.8888
# Epoch 49/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2507 - binary_accuracy: 0.8868 - val_loss: 0.2472 - val_binary_accuracy: 0.8896
# Epoch 50/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2503 - binary_accuracy: 0.8872 - val_loss: 0.2469 - val_binary_accuracy: 0.8906

# %% [markdown]
# Descomentar la siguiente celda para guardar los pesos del autoencoder.

# %%
# path = 'ruta a archivo'
# autoencoder.save_weights(path + ".h5")

# %% [markdown]
# Descomentar la siguiente celda para cargar los pesos del autencoder

# %%
# # path = 'ruta a archivo'

# # load weights into  model
# autoencoder.load_weights(path + ".h5")


# # # Si fuesemos a reentrenar necesitariamos compilar el modelo de nuevo
# # autoencoder.compile(optimizer='adam')

# %% [markdown]
# ## Testing
# En primer lugar vamos a pasar la red sobre el conjunto de test para ver si ha
# generalizado.
#
# ### Carga y preprocesado de datos de test
# Para esto tenemos que cargar en primer lugar el conjunto de test.

# %%
testing_in = os.listdir(os.path.join(data_path, "original_testing"))
testing_label = os.listdir(os.path.join(data_path, "ground_truth_testing"))

# Ordenamos las imágenes por sequencia
testing_in.sort(key=lambda x: (int(x.split("_")[0].split("l")[1]), int(x.split(".")[0].split("_")[1])))
testing_label.sort(key=lambda x: (int(x.split("_")[0].split("t")[1]), int(x.split(".")[0].split("_")[1])))
x_test = [plt_image.imread(os.path.join(data_path, "original_testing", name)) for name in testing_in[:100]]
y_test = [plt_image.imread(os.path.join(data_path, "ground_truth_testing", name)) for name in testing_label[:100]]

# %% [markdown]
# Aplicaremos las mismas transformaciones que en el conjunto de entrenamiento, es decir, redimensionaremos las imágenes hasta el tamaño de entrada de la red y normalizaremos los datos.

# %%
# Descomentar si fuese necesario redimensionar los datos
"""import cv2
for i in range(len(x_test)):
    x_test[i] = cv2.resize(x_test[i], (128, 128))
    y_test[i] = cv2.resize(y_test[i], (128, 128))"""
# Out:
# 'import cv2\nfor i in range(len(x_test)):\n    x_test[i] = cv2.resize(x_test[i], (128, 128))\n    y_test[i] = cv2.resize(y_test[i], (128, 128))'

# %%
# Normalizamos los datos de entrada en rango [0, 1]
x_test = np.array(x_test) / 255.
y_test = np.array(y_test) / 255.
y_test = np.expand_dims(y_test[:, :, :, 1], axis=-1)

# %% [markdown]
# La función evaluate realiza un predict sobre cada entrada del conjunto de test y extrae las métricas que hayamos indicado al compilar el modelo.

# %%
autoencoder.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 13/13 [==============================] - 0s 7ms/step - loss: 1.5657 - binary_accuracy: 0.6446
# [1.5657172203063965, 0.6445873975753784]

# %% [markdown]
# Por último, vamos a visualizar algunos de los resultados.
#
# La siguiente celda selecciona varias imágenes aleatorias y muestra su salida.

# %%
figsize = 5

# Selecionamos varias imágenes aleatorias del conjunto de test
examples_index = np.random.choice(x_test.shape[0], figsize*2)
examples = x_test[examples_index]

# Realizamos la predicción con el autoencoder
predictions = autoencoder.predict(examples)

# Ponemos a 1.0 los píxeles pertenecientes al primer plano y a 0. los pertenecientes al fondo
predictions[predictions > 0.5] = 1.0
predictions[predictions <= 0.5] = 0.0

predictions = np.squeeze(predictions, axis=-1)  # (w, h, 1) -> (w, h)

# Preparamos la figura de matplotlib
num_examples_to_generate = figsize*figsize

fig = plt.figure(figsize=(15,15))
fig.suptitle('Resultados segmentación')

for i in range(figsize*2):

    plt.subplot(4, figsize, i+1)
    plt.imshow(examples[i])
    plt.subplot(4, figsize, i + 1 + figsize*2)
    plt.imshow(predictions[i], cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# # U-Net
#
# U-Net es una arquitectura basada en el autoencoder, completamente convolucional y con conexiones residuales.

# %% [markdown]
# ![u-net-architecture.png](data:image/png;base64,...)

# %% [markdown]
# Ronneberger O., Fischer P., Brox T. (2015) U-Net: Convolutional Networks for Biomedical Image Segmentation. In: Navab N., Hornegger J., Wells W., Frangi A. (eds) Medical Image Computing and Computer-Assisted Intervention – MICCAI 2015. MICCAI 2015. Lecture Notes in Computer Science, vol 9351. Springer, Cham. https://doi.org/10.1007/978-3-319-24574-4_28

# %% [markdown]
# ## Construcción de U-Net
# A continuación vamos a ver como se construiría una U-Net.
# En este caso vamos a dividir la red igualmente en dos partes: Codificador y Decodificador. La arquitectura a seguir se encuentra en el siguiente diagrama:

# %% [markdown]
# ![Unet(1).png](data:image/png;base64,...)

# %% [markdown]
# ## Datos Categóricos
# Para este ejemplo vamos a coger el mismo dataset que se ha utilizado en el ejemplo anterior y lo vamos a convertir en un problema categórico en lugar de un problema binario.
#
# Originalmente el problema de la segmentación del primer plano se ha planteado como un problema en el que los píxeles de una máscara con valor mayor que 0.5 (umbral que hemos elegido nosotros) pertenecen al primer plano y los los menores al fondo.
#
# Lo que queremos hacer ahora es convertirlo en un problema de clasificación en el que obtengamos dos máscaras, una para el primer plano y una para el fondo. Por lo tanto la máscara de segmentación que obtengamos como salida de la red estará formada por dos máscaras y tendrá forma (128, 128, 2)

# %%
y_train_foreground = y_train[:]
y_train_background = np.abs(y_train[:] - 1)  # Invertimos la máscara para crear el fondo

fig = plt.figure(figsize=(10, 10))

plt.subplot(1, 3, 1)
plt.imshow(x_train[0])

plt.subplot(1, 3, 2)
im_fg = np.squeeze(y_train_foreground[0], axis=-1)
plt.imshow(im_fg)

plt.subplot(1, 3, 3)
im_bg = np.squeeze(y_train_background[0], axis=-1)
plt.imshow(im_bg)

plt.axis('off')
plt.show()

y_train_unet = np.concatenate((y_train_background, y_train_foreground), axis=-1)
print('Train targets shape: ', y_train_unet.shape)

y_val_foreground = y_val[:]
y_val_background = np.abs(y_val[:] - 1)

y_val_unet = np.concatenate((y_val_foreground, y_val_background), axis=-1)
print('Validation targets shape: ', y_val_unet.shape)

y_test_foreground = y_test[:]
y_test_background = np.abs(y_test[:] - 1)

y_test_unet = np.concatenate((y_test_background, y_test_foreground), axis=-1)
print('Test targets shape: ',y_test_unet.shape)
# Out:
# Train targets shape:  (85, 128, 128, 2)
# Validation targets shape:  (15, 128, 128, 2)
# Test targets shape:  (100, 128, 128, 2)

# %% [markdown]
# ### Encoder

# %%
# Construir el codificador de U-Net

input_shape = (128, 128, 3)  # Definimos el tamaño de las imágenes de entrada

unet_input = Input(shape=input_shape, name='encoder_input')  # Tensor de entrada

# En este caso aplicamos MaxPooling para reducir las dimensiones de los datos poco a poco
enc1 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(unet_input)

maxpool1 = MaxPooling2D((2, 2))(enc1)

enc2 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(maxpool1)

maxpool2 = MaxPooling2D((2, 2))(enc2)

enc3 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(maxpool2)

maxpool3 = MaxPooling2D((2, 2))(enc3)

enc4 = Conv2D(filters=8,
            kernel_size=3,
            activation='relu',
            strides=1,
            padding='same')(maxpool3)

maxpool4 = MaxPooling2D((2, 2))(enc4)

huella_latente = Conv2D(filters=8,
                  kernel_size=3,
                  activation='relu',
                  strides=1,
                  padding='same')(maxpool4)

# %% [markdown]
# ### Decoder
#
# En este caso el decodificador ha de reconstruir una imagen con tamaño (128, 128, 2) que es la dimensión del ground thruth. Además, en U-Net se crean conexiones residuales entre las capas del mismo nivel del codificador y el decodificador mediante una concatenación.
#
# Es importante tener en cuenta que en este caso no se utilizan convoluciones traspuestas y por lo tanto, usar un stride=2 no va a aumentar el tamaño de los vectores. Para realizar este paso, en el codificador se ha utilizado Max Pooling y en el decodificador se tendrá que usar una operación inversa que es Up Samplig.

# %%
# Contruir el decodificador

# Aplicamos convoluciones traspuestas con stride=2 hasta alcanzar la forma (128, 128, 8)
UpSamp1 = UpSampling2D((2, 2))(huella_latente)
UpSamp1 = Concatenate()([UpSamp1, enc4])

dec1 = Conv2D(filters=8,
              kernel_size=3,
              activation='relu',
              strides=1,
              padding='same')(UpSamp1)

UpSamp2 = UpSampling2D((2, 2))(dec1)
UpSamp2 = Concatenate()([UpSamp2, enc3])

dec2 = Conv2D(filters=8,
              kernel_size=3,
              activation='relu',
              strides=1,
              padding='same')(UpSamp2)

UpSamp3 = UpSampling2D((2, 2))(dec2)
UpSamp3 = Concatenate()([UpSamp3, enc2])

dec3 = Conv2D(filters=8,
              kernel_size=3,
              activation='relu',
              strides=1,
              padding='same')(UpSamp3)

UpSamp4 = UpSampling2D((2, 2))(dec3)
UpSamp4 = Concatenate()([UpSamp4, enc1])

dec4 = Conv2D(filters=8,
              kernel_size=3,
              activation='relu',
              strides=1,
              padding='same')(UpSamp4)

# Transformamos el vector dec4 para que tenga el número de canales deseado
unet_output = Conv2DTranspose(filters=2,
                              kernel_size=1,
                              activation='linear',
                              padding='same',
                              name='decoder_output')(dec4)

unet_output = tf.keras.activations.softmax(unet_output, axis=-1)

# %%
unet =  tf.keras.models.Model(unet_input, unet_output, name='U-Net')

# %%
# unet.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4),
#                     loss=tf.keras.losses.BinaryCrossentropy(),
#                     metrics=tf.keras.metrics.BinaryAccuracy(threshold=0.5))
unet.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4),
                    loss=tf.keras.losses.CategoricalCrossentropy(),
                    metrics=tf.keras.metrics.CategoricalAccuracy())

unet.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 8)  224         encoder_input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 8)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 8)    584         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 8)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 8)    584         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 8)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 8)    584         max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 8)      0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 8)      584         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 16, 16, 8)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 16)   0           up_sampling2d_4[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 8)    1160        concatenate_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 8)    0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 16)   0           up_sampling2d_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 8)    1160        concatenate_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 8)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 16)   0           up_sampling2d_6[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 8)    1160        concatenate_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 8)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 16) 0           up_sampling2d_7[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 8)  1160        concatenate_7[0][0]
# __________________________________________________________________________________________________
# decoder_output (Conv2DTranspose (None, 128, 128, 2)  18          conv2d_21[0][0]
# __________________________________________________________________________________________________
# tf.nn.softmax_1 (TFOpLambda)    (None, 128, 128, 2)  0           decoder_output[0][0]
# ==================================================================================================
# Total params: 7,218
# Trainable params: 7,218
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Entrenar U-Net

# %%
batch_size = 8
epochs = 50

unet.fit(x_train, y_train_unet, epochs=epochs, batch_size=batch_size, shuffle=True, validation_data=(x_val, y_val_unet))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 72ms/step - loss: 0.6938 - categorical_accuracy: 0.5015 - val_loss: 0.7303 - val_categorical_accuracy: 0.2821
# Epoch 2/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.6429 - categorical_accuracy: 0.7130 - val_loss: 0.7882 - val_categorical_accuracy: 0.2949
# Epoch 3/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.6126 - categorical_accuracy: 0.7021 - val_loss: 0.8344 - val_categorical_accuracy: 0.3000
# Epoch 4/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.5933 - categorical_accuracy: 0.7020 - val_loss: 0.8822 - val_categorical_accuracy: 0.2969
# Epoch 5/50
# 11/11 [==============================] - 1s 59ms/step - loss: 0.5780 - categorical_accuracy: 0.7019 - val_loss: 0.9350 - val_categorical_accuracy: 0.2975
# Epoch 6/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.5659 - categorical_accuracy: 0.7013 - val_loss: 0.9890 - val_categorical_accuracy: 0.2980
# Epoch 7/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.5565 - categorical_accuracy: 0.7010 - val_loss: 1.0366 - val_categorical_accuracy: 0.2980
# Epoch 8/50
# 11/11 [==============================] - 1s 64ms/step - loss: 0.5486 - categorical_accuracy: 0.7011 - val_loss: 1.0716 - val_categorical_accuracy: 0.2979
# Epoch 9/50
# 11/11 [==============================] - 1s 59ms/step - loss: 0.5414 - categorical_accuracy: 0.7016 - val_loss: 1.0997 - val_categorical_accuracy: 0.2970
# Epoch 10/50
# 11/11 [==============================] - 1s 64ms/step - loss: 0.5337 - categorical_accuracy: 0.7028 - val_loss: 1.1313 - val_categorical_accuracy: 0.2951
# Epoch 11/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.5244 - categorical_accuracy: 0.7053 - val_loss: 1.1543 - val_categorical_accuracy: 0.2912
# Epoch 12/50
# 11/11 [==============================] - 1s 59ms/step - loss: 0.5118 - categorical_accuracy: 0.7110 - val_loss: 1.1783 - val_categorical_accuracy: 0.2814
# Epoch 13/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.4917 - categorical_accuracy: 0.7283 - val_loss: 1.2219 - val_categorical_accuracy: 0.2500
# Epoch 14/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.4552 - categorical_accuracy: 0.7738 - val_loss: 1.3309 - val_categorical_accuracy: 0.1921
# Epoch 15/50
# 11/11 [==============================] - 1s 67ms/step - loss: 0.3977 - categorical_accuracy: 0.8283 - val_loss: 1.6279 - val_categorical_accuracy: 0.1445
# Epoch 16/50
# 11/11 [==============================] - 1s 63ms/step - loss: 0.3216 - categorical_accuracy: 0.8671 - val_loss: 2.1706 - val_categorical_accuracy: 0.1206
# Epoch 17/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.2613 - categorical_accuracy: 0.8887 - val_loss: 2.7064 - val_categorical_accuracy: 0.0992
# Epoch 18/50
# 11/11 [==============================] - 1s 59ms/step - loss: 0.2195 - categorical_accuracy: 0.9096 - val_loss: 3.2431 - val_categorical_accuracy: 0.0782
# Epoch 19/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.1873 - categorical_accuracy: 0.9289 - val_loss: 3.7650 - val_categorical_accuracy: 0.0628
# Epoch 20/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.1623 - categorical_accuracy: 0.9427 - val_loss: 4.0369 - val_categorical_accuracy: 0.0509
# Epoch 21/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.1416 - categorical_accuracy: 0.9522 - val_loss: 4.5132 - val_categorical_accuracy: 0.0414
# Epoch 22/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.1248 - categorical_accuracy: 0.9600 - val_loss: 4.8137 - val_categorical_accuracy: 0.0361
# Epoch 23/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.1127 - categorical_accuracy: 0.9636 - val_loss: 5.3034 - val_categorical_accuracy: 0.0356
# Epoch 24/50
# 11/11 [==============================] - 1s 62ms/step - loss: 0.1038 - categorical_accuracy: 0.9665 - val_loss: 5.5346 - val_categorical_accuracy: 0.0303
# Epoch 25/50
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0972 - categorical_accuracy: 0.9683 - val_loss: 5.6969 - val_categorical_accuracy: 0.0307
# Epoch 26/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0919 - categorical_accuracy: 0.9703 - val_loss: 6.2113 - val_categorical_accuracy: 0.0286
# Epoch 27/50
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0877 - categorical_accuracy: 0.9713 - val_loss: 6.1880 - val_categorical_accuracy: 0.0283
# Epoch 28/50
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0855 - categorical_accuracy: 0.9718 - val_loss: 6.5645 - val_categorical_accuracy: 0.0248
# Epoch 29/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0820 - categorical_accuracy: 0.9734 - val_loss: 6.7405 - val_categorical_accuracy: 0.0239
# Epoch 30/50
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0778 - categorical_accuracy: 0.9754 - val_loss: 6.7841 - val_categorical_accuracy: 0.0242
# Epoch 31/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0754 - categorical_accuracy: 0.9763 - val_loss: 7.0297 - val_categorical_accuracy: 0.0225
# Epoch 32/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0731 - categorical_accuracy: 0.9769 - val_loss: 7.2990 - val_categorical_accuracy: 0.0224
# Epoch 33/50
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0722 - categorical_accuracy: 0.9770 - val_loss: 7.1893 - val_categorical_accuracy: 0.0239
# Epoch 34/50
# 11/11 [==============================] - 1s 59ms/step - loss: 0.0718 - categorical_accuracy: 0.9768 - val_loss: 7.6373 - val_categorical_accuracy: 0.0225
# Epoch 35/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0683 - categorical_accuracy: 0.9786 - val_loss: 7.5930 - val_categorical_accuracy: 0.0203
# Epoch 36/50
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0667 - categorical_accuracy: 0.9792 - val_loss: 7.7445 - val_categorical_accuracy: 0.0198
# Epoch 37/50
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0654 - categorical_accuracy: 0.9797 - val_loss: 7.8607 - val_categorical_accuracy: 0.0193
# Epoch 38/50
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0642 - categorical_accuracy: 0.9801 - val_loss: 7.9312 - val_categorical_accuracy: 0.0189
# Epoch 39/50
# 11/11 [==============================] - 1s 65ms/step - loss: 0.0636 - categorical_accuracy: 0.9802 - val_loss: 8.1614 - val_categorical_accuracy: 0.0192
# Epoch 40/50
# 11/11 [==============================] - 1s 63ms/step - loss: 0.0620 - categorical_accuracy: 0.9809 - val_loss: 8.1355 - val_categorical_accuracy: 0.0182
# Epoch 41/50
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0611 - categorical_accuracy: 0.9812 - val_loss: 8.1624 - val_categorical_accuracy: 0.0191
# Epoch 42/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0605 - categorical_accuracy: 0.9813 - val_loss: 8.5379 - val_categorical_accuracy: 0.0191
# Epoch 43/50
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0612 - categorical_accuracy: 0.9807 - val_loss: 8.4213 - val_categorical_accuracy: 0.0175
# Epoch 44/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0587 - categorical_accuracy: 0.9819 - val_loss: 8.7296 - val_categorical_accuracy: 0.0189
# Epoch 45/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0590 - categorical_accuracy: 0.9816 - val_loss: 8.4741 - val_categorical_accuracy: 0.0183
# Epoch 46/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0574 - categorical_accuracy: 0.9824 - val_loss: 8.6605 - val_categorical_accuracy: 0.0167
# Epoch 47/50
# 11/11 [==============================] - 1s 61ms/step - loss: 0.0562 - categorical_accuracy: 0.9828 - val_loss: 8.8396 - val_categorical_accuracy: 0.0166
# Epoch 48/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0562 - categorical_accuracy: 0.9826 - val_loss: 8.7833 - val_categorical_accuracy: 0.0166
# Epoch 49/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0555 - categorical_accuracy: 0.9829 - val_loss: 8.8901 - val_categorical_accuracy: 0.0163
# Epoch 50/50
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0547 - categorical_accuracy: 0.9832 - val_loss: 9.0541 - val_categorical_accuracy: 0.0161

# %% [markdown]
# ## Testing U-Net
# Vamos a pasar la red sobre el conjunto de test para ver si ha
# generalizado.

# %% [markdown]
# La función evaluate realiza un predict sobre cada entrada del conjunto de test y extrae las métricas que hayamos indicado al compilar el modelo.

# %%
unet.evaluate(x_test, y_test_unet, batch_size=batch_size)
# Out:
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3169 - categorical_accuracy: 0.9072
# [0.31691908836364746, 0.9071771502494812]

# %% [markdown]
# Por último, vamos a visualizar algunos de los resultados.
#
# La siguiente celda selecciona varias imágenes aleatorias y muestra su salida.

# %%
# Selecionamos varias imágenes aleatorias del conjunto de test
examples_index = np.random.choice(x_test.shape[0], figsize*2)
examples = x_test[examples_index]

# Realizamos la predicción con el autoencoder
predictions = unet.predict(examples)

predictions = np.argmax(predictions, axis=-1)  # (128, 128, n)

# Preparamos la figura de matplotlib
figsize = 5
num_examples_to_generate = figsize*figsize

fig = plt.figure(figsize=(15, 15))
fig.suptitle('Resultados segmentación')

for i in range(figsize*2):

    plt.subplot(4, figsize, i+1)
    plt.imshow(examples[i])
    plt.subplot(4, figsize, i + 1 + figsize*2)
    plt.imshow(predictions[i], cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# A continuación vamos a realizar una visualización de los mapas de probabilidad generado para cada máscara

# %%
# Selecionamos varias imágenes aleatorias del conjunto de test
examples_index = np.random.choice(x_test.shape[0], 2)
examples = x_test[examples_index]

# Realizamos la predicción con el autoencoder
predictions = unet.predict(examples)

predictions_bg = predictions[:, :, :, 0]
predictions_fg = predictions[:, :, :, 1]

# Preparamos la figura de matplotlib
num_examples_to_generate = figsize*figsize

fig = plt.figure(figsize=(10, 10))

plt.subplot(2, 3, 1)  #, title='Original')
plt.imshow(examples[0])

plt.subplot(2, 3, 2)
plt.imshow(predictions_fg[0], cmap='gray')

plt.subplot(2, 3, 3)
plt.imshow(predictions_bg[0], cmap='gray')

plt.subplot(2, 3, 4)
plt.imshow(examples[1])

plt.subplot(2, 3, 5)
plt.imshow(predictions_fg[1], cmap='gray')

plt.subplot(2, 3, 6)
plt.imshow(predictions_bg[1], cmap='gray')

plt.axis('off')
plt.show()

# %% [markdown]
# # Experimentos
#
#
# *   ¿Se puede implementar una Unet utilizando convoluciones traspuestas para decodificar la huella latente?
# *   Si en la salida de la red tenemos una máscara con valores entre 0 y 1 por cada clase, ¿cuándo consideramos que ese píxel pertenece a la clase del objeto que estamos segmentando?

# %% [markdown]
# # Otros recursos
# A continuación os dejamos algunos recursos con información sobre plataformas de cómputo para Deep Learning como Tensorflow, keras y pytorch.
#
# También teneis algunos enlaces a datasets de segmentación pequeños que se pueden utilizar para talleres y pruebas y a sitios web donde podeis encontrar otros datasets.

# %% [markdown]
# ## Recursos y tutoriales
#
# TensorFlow (TF2): https://www.tensorflow.org/
#
# Keras: https://keras.io/
#
# *   Tutoriales TF2: https://www.tensorflow.org/tutorials
#   *   Segmentación: https://www.tensorflow.org/tutorials/images/segmentation
#   *   Autoencoder variacional: https://www.tensorflow.org/tutorials/generative/cvae
# *   Tutoriales keras: https://keras.io/examples/
#   *   Segmentación con U-Net: https://keras.io/examples/vision/oxford_pets_image_segmentation/
#   *   Autoencoder para denoising: https://keras.io/examples/vision/autoencoder/
#   *   Segementación con DeepLabV3+: https://keras.io/examples/vision/deeplabv3_plus/

# %% [markdown]
# ## Datasets
#
# * Datasets interesantes para realizar pequeñas pruebas
#   * ConferenceVideoSegmentationDataset: https://github.com/kuangzijian/Flow-Based-Video-Segmentation
#     * Data url: https://drive.google.com/file/d/13JKwoCaoSWQAjJ1YLVfV6AHvm8by09fP/view
#     * Cuatro videos estilo conferencia con segmentaciones de las personas.
#     * Dataset creado semi artificialmente utilizando una pantalla verde de fondo
#
#   * The Oxford-IIIT Pet Dataset: https://www.robots.ox.ac.uk/~vgg/data/pets/
#     * 36 tipos de máscotas segmentadas con 200 imágenes por tipo
#     * Anotaciones de backgroud, edges y foreground.
#
# * Colecciones de datasets:
#   * Papers with Code: https://paperswithcode.com/datasets?q=segmentation&v=lst&o=match&page=1
#   * Kaggle: https://www.kaggle.com/datasets
#   * UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/index.php
#   * Google Dataset Search: https://datasetsearch.research.google.com/
#   * Visual Data: https://visualdata.io/discovery
